# %%
import pandas as pd
messages=pd.read_csv('SMSSpamCollection',
                    sep='\t',names=["label","message"])

# %%
messages
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
## Data Cleaning and Data Preorocessing:---->
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
wordlemmatize=WordNetLemmatizer()

# %%
corpus=[]
for i in range(0,len(messages)):
    review=re.sub('^a-zA-z]', ' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[wordlemmatize.lemmatize(word) for word in review if not word in stopwords.words('english')]
    corpus.append(review)

# %%
corpus
# Out:
# [['go',
#   'jurong',
#   'point,',
#   'crazy..',
#   'available',
#   'bugis',
#   'n',
#   'great',
#   'world',
#   'la',
#   'e',
#   'buffet...',
#   'cine',
#   'got',
#   'amore',
#   'wat...'],
#  ['ok', 'lar...', 'joking', 'wif', 'u', 'oni...'],
#  ['free',
#   'entry',
#   '2',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   '21st',
#   'may',
#   '2005.',
#   'text',
#   'fa',
#   '87121',
#   'receive',
#   'entry',
#   'question(std',
#   'txt',
#   "rate)t&c's",
#   'apply',
#   "08452810075over18's"],
#  ['u', 'dun', 'say', 'early', 'hor...', 'u', 'c', 'already', 'say...'],
#  ['nah', 'think', 'go', 'usf,', 'life', 'around', 'though'],
#  ['freemsg',
#   'hey',
#   'darling',
#   '3',
#   "week's",
#   'word',
#   'back!',
#   "i'd",
#   'like',
#   'fun',
#   'still?',
#   'tb',
#   'ok!',
#   'xxx',
#   'std',
#   'chgs',
#   'send,',
#   '£1.50',
#   'rcv'],
#  ['even',
#   'brother',
#   'like',
#   'speak',
#   'me.',
#   'treat',
#   'like',
#   'aid',
#   'patent.'],
#  ['per',
#   'request',
#   "'melle",
#   'melle',
#   '(oru',
#   'minnaminunginte',
#   'nurungu',
#   "vettam)'",
#   'set',
#   'callertune',
#   'callers.',
#   'press',
#   '*9',
#   'copy',
#   'friend',
#   'callertune'],
#  ['winner!!',
#   'valued',
#   'network',
#   'customer',
#   'selected',
#   'receivea',
#   '£900',
#   'prize',
#   'reward!',
#   'claim',
#   'call',
#   '09061701461.',
#   'claim',
#   'code',
#   'kl341.',
#   'valid',
#   '12',
#   'hour',
#   'only.'],
#  ['mobile',
#   '11',
#   'month',
#   'more?',
#   'u',
#   'r',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'mobile',
#   'camera',
#   'free!',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   '08002986030'],
#  ["i'm",
#   'gonna',
#   'home',
#   'soon',
#   'want',
#   'talk',
#   'stuff',
#   'anymore',
#   'tonight,',
#   'k?',
#   "i've",
#   'cried',
#   'enough',
#   'today.'],
#  ['six',
#   'chance',
#   'win',
#   'cash!',
#   '100',
#   '20,000',
#   'pound',
#   'txt>',
#   'csh11',
#   'send',
#   '87575.',
#   'cost',
#   '150p/day,',
#   '6days,',
#   '16+',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   '4',
#   'info'],
#  ['urgent!',
#   '1',
#   'week',
#   'free',
#   'membership',
#   '£100,000',
#   'prize',
#   'jackpot!',
#   'txt',
#   'word:',
#   'claim',
#   'no:',
#   '81010',
#   't&c',
#   'www.dbuk.net',
#   'lccltd',
#   'pobox',
#   '4403ldnw1a7rw18'],
#  ["i've",
#   'searching',
#   'right',
#   'word',
#   'thank',
#   'breather.',
#   'promise',
#   'wont',
#   'take',
#   'help',
#   'granted',
#   'fulfil',
#   'promise.',
#   'wonderful',
#   'blessing',
#   'times.'],
#  ['date', 'sunday', 'will!!'],
#  ['xxxmobilemovieclub:',
#   'use',
#   'credit,',
#   'click',
#   'wap',
#   'link',
#   'next',
#   'txt',
#   'message',
#   'click',
#   'here>>',
#   'http://wap.',
#   'xxxmobilemovieclub.com?n=qjkgighjjgcbl'],
#  ['oh', "k...i'm", 'watching', 'here:)'],
#  ['eh',
#   'u',
#   'remember',
#   '2',
#   'spell',
#   'name...',
#   'yes',
#   'did.',
#   'v',
#   'naughty',
#   'make',
#   'v',
#   'wet.'],
#  ['fine', 'that\x92s', 'way', 'u', 'feel.', 'that\x92s', 'way', 'gota', 'b'],
#  ['england',
#   'v',
#   'macedonia',
#   '-',
#   'dont',
#   'miss',
#   'goals/team',
#   'news.',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   '87077',
#   'eg',
#   'england',
#   '87077',
#   'try:wales,',
#   'scotland',
#   '4txt/ú1.20',
#   'poboxox36504w45wq',
#   '16+'],
#  ['seriously', 'spell', 'name?'],
#  ['i‘m', 'going', 'try', '2', 'month', 'ha', 'ha', 'joking'],
#  ['ü', 'pay', 'first', 'lar...', 'da', 'stock', 'comin...'],
#  ['aft',
#   'finish',
#   'lunch',
#   'go',
#   'str',
#   'lor.',
#   'ard',
#   '3',
#   'smth',
#   'lor.',
#   'u',
#   'finish',
#   'ur',
#   'lunch',
#   'already?'],
#  ['ffffffffff.', 'alright', 'way', 'meet', 'sooner?'],
#  ['forced',
#   'eat',
#   'slice.',
#   "i'm",
#   'really',
#   'hungry',
#   'tho.',
#   'sucks.',
#   'mark',
#   'getting',
#   'worried.',
#   'know',
#   "i'm",
#   'sick',
#   'turn',
#   'pizza.',
#   'lol'],
#  ['lol', 'always', 'convincing.'],
#  ['catch',
#   'bus',
#   '?',
#   'frying',
#   'egg',
#   '?',
#   'make',
#   'tea?',
#   'eating',
#   "mom's",
#   'left',
#   'dinner',
#   '?',
#   'feel',
#   'love',
#   '?'],
#  ["i'm",
#   'back',
#   '&amp;',
#   "we're",
#   'packing',
#   'car',
#   'now,',
#   "i'll",
#   'let',
#   'know',
#   "there's",
#   'room'],
#  ['ahhh.', 'work.', 'vaguely', 'remember', 'that!', 'feel', 'like?', 'lol'],
#  ['wait',
#   "that's",
#   'still',
#   'clear,',
#   'sure',
#   'sarcastic',
#   "that's",
#   'x',
#   'want',
#   'live',
#   'u'],
#  ['yeah',
#   'got',
#   '2',
#   'v',
#   'apologetic.',
#   'n',
#   'fallen',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'got',
#   'caught',
#   'that.',
#   'till',
#   '2!',
#   'go',
#   'there!',
#   'badly',
#   'cheers.',
#   'you?'],
#  ['k', 'tell', 'anything', 'you.'],
#  ['fear', 'fainting', 'housework', 'did?', 'quick', 'cuppa'],
#  ['thanks',
#   'subscription',
#   'ringtone',
#   'uk',
#   'mobile',
#   'charged',
#   '£5/month',
#   'please',
#   'confirm',
#   'replying',
#   'yes',
#   'no.',
#   'reply',
#   'charged'],
#  ['yup...',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'timing',
#   'msg',
#   'ü',
#   'again...',
#   'xuhui',
#   'going',
#   'learn',
#   '2nd',
#   'may',
#   'lesson',
#   '8am'],
#  ['oops,', "i'll", 'let', 'know', "roommate's", 'done'],
#  ['see', 'letter', 'b', 'car'],
#  ['anything', 'lor...', 'u', 'decide...'],
#  ['hello!',
#   "how's",
#   'saturday',
#   'go?',
#   'texting',
#   'see',
#   'decided',
#   'anything',
#   'tomo.',
#   "i'm",
#   'trying',
#   'invite',
#   'anything!'],
#  ['pls',
#   'go',
#   'ahead',
#   'watts.',
#   'wanted',
#   'sure.',
#   'great',
#   'weekend.',
#   'abiola'],
#  ['forget',
#   'tell',
#   '?',
#   'want',
#   ',',
#   'need',
#   'you,',
#   'crave',
#   '...',
#   '...',
#   'love',
#   'sweet',
#   'arabian',
#   'steed',
#   '...',
#   'mmmmmm',
#   '...',
#   'yummy'],
#  ['07732584351',
#   '-',
#   'rodger',
#   'burn',
#   '-',
#   'msg',
#   '=',
#   'tried',
#   'call',
#   'reply',
#   'sm',
#   'free',
#   'nokia',
#   'mobile',
#   '+',
#   'free',
#   'camcorder.',
#   'please',
#   'call',
#   '08000930705',
#   'delivery',
#   'tomorrow'],
#  ['seeing?'],
#  ['great!',
#   'hope',
#   'like',
#   'man',
#   'well',
#   'endowed.',
#   '&lt;#&gt;',
#   'inches...'],
#  ['calls..messages..missed', 'call'],
#  ['get', 'hep', 'b', 'immunisation', 'nigeria.'],
#  ['fair', 'enough,', 'anything', 'going', 'on?'],
#  ['yeah',
#   'hopefully,',
#   'tyler',
#   "can't",
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['u',
#   'know',
#   'stubborn',
#   'am.',
#   'even',
#   'want',
#   'go',
#   'hospital.',
#   'kept',
#   'telling',
#   'mark',
#   "i'm",
#   'weak',
#   'sucker.',
#   'hospital',
#   'weak',
#   'suckers.'],
#  ['thinked', 'me.', 'first', 'time', 'saw', 'class.'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   '&lt;#&gt;',
#   ',',
#   'half',
#   'eighth',
#   'smarter',
#   'though',
#   'get',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   '&lt;#&gt;'],
#  ['k',
#   'fyi',
#   'x',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   "he's",
#   'crashing',
#   'place',
#   'tonight'],
#  ['wow.',
#   'never',
#   'realized',
#   'embarassed',
#   'accomodations.',
#   'thought',
#   'liked',
#   'it,',
#   'since',
#   'best',
#   'could',
#   'always',
#   'seemed',
#   'happy',
#   '"the',
#   'cave".',
#   "i'm",
#   'sorry',
#   'give.',
#   "i'm",
#   'sorry',
#   'offered.',
#   "i'm",
#   'sorry',
#   'room',
#   'embarassing.'],
#  ['sms.',
#   'ac',
#   'sptv:',
#   'new',
#   'jersey',
#   'devil',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey.',
#   'correct',
#   'incorrect?',
#   'end?',
#   'reply',
#   'end',
#   'sptv'],
#  ['know', 'mallika', 'sherawat', 'yesterday?', 'find', '@', '&lt;url&gt;'],
#  ['congrats!',
#   '1',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   '2',
#   'yours.',
#   'call',
#   '09061209465',
#   'now!',
#   'c',
#   'suprman',
#   'v,',
#   'matrix3,',
#   'starwars3,',
#   'etc',
#   '4',
#   'free!',
#   'bx420-ip4-5we.',
#   '150pm.',
#   'dont',
#   'miss',
#   'out!'],
#  ['sorry,', "i'll", 'call', 'later', 'meeting.'],
#  ['tell', 'reached'],
#  ['yes..gauti', 'sehwag', 'odi', 'series.'],
#  ['gonna',
#   'pick',
#   '$1',
#   'burger',
#   'way',
#   'home.',
#   "can't",
#   'even',
#   'move.',
#   'pain',
#   'killing',
#   'me.'],
#  ['ha', 'ha', 'ha', 'good', 'joke.', 'girl', 'situation', 'seekers.'],
#  ['part', 'checking', 'iq'],
#  ['sorry', 'roommate', 'took', 'forever,', 'ok', 'come', 'now?'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'said',
#   'wun',
#   'cut',
#   'v',
#   'short.',
#   'said',
#   'cut',
#   'look',
#   'nice.'],
#  ['valued',
#   'customer,',
#   'pleased',
#   'advise',
#   'following',
#   'recent',
#   'review',
#   'mob',
#   'no.',
#   'awarded',
#   '£1500',
#   'bonus',
#   'prize,',
#   'call',
#   '09066364589'],
#  ['today',
#   '"song',
#   'dedicated',
#   'day.."',
#   'song',
#   'u',
#   'dedicate',
#   'me?',
#   'send',
#   'ur',
#   'valuable',
#   'frnds',
#   'first',
#   'rply',
#   'me...'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'eurodisinc',
#   'trav,',
#   'aco&entry41',
#   '£1000.',
#   'claim',
#   'txt',
#   'dis',
#   '87121',
#   '18+6*£1.50(morefrmmob.',
#   'shracomorsglsuplt)10,',
#   'ls1',
#   '3aj'],
#  ['hear', 'new', '"divorce', 'barbie"?', 'come', "ken's", 'stuff!'],
#  ['plane', 'give', 'month', 'end.'],
#  ['wah', 'lucky', 'man...', 'save', 'money...', 'hee...'],
#  ['finished', 'class', 'you.'],
#  ['hi', 'babe', 'im', 'home', 'wanna', 'something?', 'xx'],
#  ['k..k:)where', 'you?how', 'performed?'],
#  ['u', 'call', 'now...'],
#  ['waiting', 'machan.', 'call', 'free.'],
#  ['thats', 'cool.', 'gentleman', 'treat', 'dignity', 'respect.'],
#  ['like', 'people', 'much:)', 'shy', 'pa.'],
#  ['operate', '&lt;#&gt;'],
#  ['here.', 'still', 'looking', 'job.', 'much', "ta's", 'earn', 'there.'],
#  ['sorry,', "i'll", 'call', 'later'],
#  ['k.', 'call', 'ah?'],
#  ['ok', 'way', 'home', 'hi', 'hi'],
#  ['place', 'man'],
#  ['yup', 'next', 'stop.'],
#  ['call', 'later,', 'network.', 'urgnt,', 'sm', 'me.'],
#  ['real',
#   'u',
#   'getting',
#   'yo?',
#   'need',
#   '2',
#   'ticket',
#   'one',
#   'jacket',
#   "i'm",
#   'done.',
#   'already',
#   'used',
#   'multis.'],
#  ['yes',
#   'started',
#   'send',
#   'request',
#   'make',
#   'pain',
#   'came',
#   'back',
#   "i'm",
#   'back',
#   'bed.',
#   'double',
#   'coin',
#   'factory',
#   'too.',
#   'gotta',
#   'cash',
#   'nitros.'],
#  ["i'm", 'really', 'still', 'tonight', 'babe'],
#  ['ela', 'kano.,il', 'download,', 'come', 'wen', 'ur', 'free..'],
#  ['yeah',
#   'do!',
#   'don‘t',
#   'stand',
#   'close',
#   'tho-',
#   'you‘ll',
#   'catch',
#   'something!'],
#  ['sorry',
#   'pain.',
#   'ok',
#   'meet',
#   'another',
#   'night?',
#   'spent',
#   'late',
#   'afternoon',
#   'casualty',
#   'mean',
#   'done',
#   'stuff42moro',
#   'includes',
#   'time',
#   'sheet',
#   'that.',
#   'sorry.'],
#  ['smile',
#   'pleasure',
#   'smile',
#   'pain',
#   'smile',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'sum1',
#   'hurt',
#   'u',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'see',
#   'u',
#   'smiling!!'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   '0800',
#   '169',
#   '6031',
#   '10am-9pm',
#   'guaranteed',
#   '£1000',
#   'cash',
#   '£5000',
#   'prize!'],
#  ['havent',
#   'planning',
#   'buy',
#   'later.',
#   'check',
#   'already',
#   'lido',
#   'got',
#   '530',
#   'show',
#   'e',
#   'afternoon.',
#   'u',
#   'finish',
#   'work',
#   'already?'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected.',
#   'simply',
#   'text',
#   'password',
#   '"mix"',
#   '85069',
#   'verify.',
#   'get',
#   'usher',
#   'britney.',
#   'fml,',
#   'po',
#   'box',
#   '5249,',
#   'mk17',
#   '92h.',
#   '450ppw',
#   '16'],
#  ['watching', 'telugu', 'movie..wat', 'abt', 'u?'],
#  ['see.', 'finish', 'load', 'loan', 'pay'],
#  ['hi.',
#   'wk',
#   'ok',
#   '-',
#   'hols',
#   'now!',
#   'yes',
#   'bit',
#   'run.',
#   'forgot',
#   'hairdresser',
#   'appointment',
#   'four',
#   'need',
#   'get',
#   'home',
#   'n',
#   'shower',
#   'beforehand.',
#   'cause',
#   'prob',
#   'u?"'],
#  ['see', 'cup', 'coffee', 'animation'],
#  ['please', 'text', 'anymore.', 'nothing', 'else', 'say.'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'legal!',
#   'wen',
#   'pick',
#   'up?',
#   'u',
#   'ave',
#   'x',
#   'am',
#   'xx'],
#  ["i'm",
#   'still',
#   'looking',
#   'car',
#   'buy.',
#   'gone',
#   '4the',
#   'driving',
#   'test',
#   'yet.'],
#  ['per',
#   'request',
#   "'melle",
#   'melle',
#   '(oru',
#   'minnaminunginte',
#   'nurungu',
#   "vettam)'",
#   'set',
#   'callertune',
#   'callers.',
#   'press',
#   '*9',
#   'copy',
#   'friend',
#   'callertune'],
#  ['wow.',
#   'right!',
#   'mean',
#   'that.',
#   'guess',
#   'gave',
#   'boston',
#   'men',
#   'changed',
#   'search',
#   'location',
#   'nyc,',
#   'something',
#   'changed.',
#   'cuz',
#   'signin',
#   'page',
#   'still',
#   'say',
#   'boston.'],
#  ['umma', 'life', 'vava', 'umma', 'love', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'wish',
#   'birthday.',
#   'thanks',
#   'making',
#   'birthday',
#   'truly',
#   'memorable.'],
#  ['aight,', "i'll", 'hit', 'get', 'cash'],
#  ['would',
#   'ip',
#   'address',
#   'test',
#   'considering',
#   'computer',
#   'minecraft',
#   'server'],
#  ['know!',
#   'grumpy',
#   'old',
#   'people.',
#   'mom',
#   'like',
#   'better',
#   'lying.',
#   'always',
#   'one',
#   'play',
#   'jokes...'],
#  ['dont', 'worry.', 'guess', "he's", 'busy.'],
#  ['plural', 'noun', 'research?'],
#  ['going', 'dinner.msg', 'after.'],
#  ["i'm",
#   'ok',
#   'wif',
#   'co',
#   'like',
#   '2',
#   'try',
#   'new',
#   'things.',
#   'scared',
#   'u',
#   'dun',
#   'like',
#   'mah.',
#   'co',
#   'u',
#   'said',
#   'loud.'],
#  ['gent!',
#   'trying',
#   'contact',
#   'you.',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   '£1000',
#   'prize',
#   'guaranteed.',
#   'call',
#   '09064012160.',
#   'claim',
#   'code',
#   'k52.',
#   'valid',
#   '12hrs',
#   'only.',
#   '150ppm'],
#  ['wa,',
#   'ur',
#   'openin',
#   'sentence',
#   'formal...',
#   'anyway,',
#   "i'm",
#   'fine',
#   'too,',
#   'juz',
#   'tt',
#   "i'm",
#   'eatin',
#   'much',
#   'n',
#   'puttin',
#   'weight...haha...',
#   'anythin',
#   'special',
#   'happened?'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said,',
#   "''",
#   'happy',
#   "b'day",
#   'bos',
#   "!!''.",
#   'felt',
#   'special.',
#   'askd',
#   '4',
#   'lunch.',
#   'lunch',
#   'invited',
#   'apartment.',
#   'went',
#   'there.'],
#  ['winner',
#   'u',
#   'specially',
#   'selected',
#   '2',
#   'receive',
#   '£1000',
#   '4*',
#   'holiday',
#   '(flights',
#   'inc)',
#   'speak',
#   'live',
#   'operator',
#   '2',
#   'claim',
#   '0871277810910p/min',
#   '(18+)'],
#  ['goodo!',
#   'yes',
#   'must',
#   'speak',
#   'friday',
#   '-',
#   'egg-potato',
#   'ratio',
#   'tortilla',
#   'needed!'],
#  ['hmm...my',
#   'uncle',
#   'informed',
#   "he's",
#   'paying',
#   'school',
#   'directly.',
#   'pls',
#   'buy',
#   'food.'],
#  ['private!',
#   '2004',
#   'account',
#   'statement',
#   '07742676969',
#   'show',
#   '786',
#   'unredeemed',
#   'bonus',
#   'points.',
#   'claim',
#   'call',
#   '08719180248',
#   'identifier',
#   'code:',
#   '45239',
#   'expires'],
#  ['urgent!',
#   'mobile',
#   'no.',
#   'awarded',
#   '£2000',
#   'bonus',
#   'caller',
#   'prize',
#   '5/9/03',
#   'final',
#   'try',
#   'contact',
#   'u!',
#   'call',
#   'landline',
#   '09064019788',
#   'box42wr29c,',
#   '150ppm'],
#  ['new', 'address', '-apples&pairs&all', 'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   '7548',
#   'selected',
#   'receive',
#   '$350',
#   'award.',
#   'match',
#   'please',
#   'call',
#   '08712300220',
#   'quoting',
#   'claim',
#   'code',
#   '4041',
#   'standard',
#   'rate',
#   'app'],
#  ['going', 'sao', 'mu', 'today.', 'done', '12'],
#  ['ü', 'predict', 'wat', 'time', "ü'll", 'finish', 'buying?'],
#  ['good', 'stuff,', 'do.'],
#  ['know,yetunde',
#   'sent',
#   'money',
#   'yet.',
#   'sent',
#   'text',
#   'bother',
#   'sending.',
#   'over,',
#   'dont',
#   'involve',
#   'anything.',
#   'imposed',
#   'anything',
#   'first',
#   'place',
#   'that,',
#   'apologise.'],
#  ['room.'],
#  ['hey',
#   'girl.',
#   'r',
#   'u?',
#   'hope',
#   'u',
#   'r',
#   'well',
#   'del',
#   'r',
#   'bak!',
#   'long',
#   'time',
#   'c!',
#   'give',
#   'call',
#   'sum',
#   'time',
#   'lucyxx'],
#  ['k..k:)how', 'much', 'cost?'],
#  ["i'm", 'home.'],
#  ['dear,', 'call', 'tmorrow.pls', 'accomodate.'],
#  ['first', 'answer', 'question.'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'q!',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'u',
#   'know',
#   'country',
#   'algarve',
#   'in?',
#   'txt',
#   'ansr',
#   '82277.',
#   '£1.50',
#   'sp:tyrone'],
#  ['want',
#   '2',
#   'get',
#   'laid',
#   'tonight?',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   '2',
#   'ur',
#   'mob?',
#   'join',
#   "uk's",
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   '69888!',
#   'nt.',
#   'ec2a.',
#   '31p.msg@150p'],
#  ['haf', 'msn.', 'yijue@hotmail.com'],
#  ['there.', 'call', 'meet'],
#  ['no.', 'check', 'room', 'befor', 'activity'],
#  ['rcv',
#   'msg',
#   'chat',
#   'svc.',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to:',
#   '69988',
#   'u',
#   'get',
#   'nothing',
#   'u',
#   'must',
#   'age',
#   'verify',
#   'yr',
#   'network',
#   '&',
#   'try'],
#  ['got',
#   'c...',
#   'lazy',
#   'type...',
#   'forgot',
#   'ü',
#   'lect...',
#   'saw',
#   'pouch',
#   'like',
#   'v',
#   'nice...'],
#  ['k,', 'text', 'way'],
#  ['sir,', 'waiting', 'mail.'],
#  ['swt',
#   'thought:',
#   '"nver',
#   'get',
#   'tired',
#   'little',
#   'thing',
#   '4',
#   'lovable',
#   'persons.."',
#   'coz..somtimes',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'hearts..',
#   'gud',
#   'ni8'],
#  ['know', 'are.', 'pls', 'open', 'back?'],
#  ['yes', 'see', 'ya', 'dot'],
#  ['whats', 'staff', 'name', 'taking', 'class', 'us?'],
#  ['freemsg',
#   'replied',
#   'text?',
#   "i'm",
#   'randy,',
#   'sexy,',
#   'female',
#   'live',
#   'local.',
#   'luv',
#   'hear',
#   'u.',
#   'netcollex',
#   'ltd',
#   '08700621170150p',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'end'],
#  ['ummma.will',
#   'call',
#   'check',
#   'in.our',
#   'life',
#   'begin',
#   'qatar',
#   'pls',
#   'pray',
#   'hard.'],
#  ['k..i', 'deleted', 'contact', 'why?'],
#  ['sindu', 'got', 'job', 'birla', 'soft', '..'],
#  ['wine', 'flowing', "i'm", 'nevering..'],
#  ['yup',
#   'thk',
#   'cine',
#   'better',
#   'co',
#   'need',
#   '2',
#   'go',
#   '2',
#   'plaza',
#   'mah.'],
#  ['ok...', 'ur', 'typical', 'reply...'],
#  ['per',
#   'request',
#   "'melle",
#   'melle',
#   '(oru',
#   'minnaminunginte',
#   'nurungu',
#   "vettam)'",
#   'set',
#   'callertune',
#   'callers.',
#   'press',
#   '*9',
#   'copy',
#   'friend',
#   'callertune'],
#  ['everywhere',
#   'dirt,',
#   'floor,',
#   'windows,',
#   'even',
#   'shirt.',
#   'sometimes',
#   'open',
#   'mouth,',
#   'come',
#   'flowing',
#   'out.',
#   'dream',
#   'world',
#   'without',
#   'you,',
#   'half',
#   'chore',
#   'too.',
#   'time',
#   'joy',
#   'me,',
#   'lot',
#   'tv',
#   'show',
#   'i.ll',
#   'see.',
#   'guess',
#   'like',
#   'thing',
#   'must',
#   'exist,',
#   'like',
#   'rain,',
#   'hail',
#   'mist,',
#   'time',
#   'done,',
#   'become',
#   'one.'],
#  ['aaooooright', 'work?'],
#  ["i'm", 'leaving', 'house', 'now...'],
#  ['hello,',
#   'love.',
#   'doing?',
#   'get',
#   'interview',
#   'today?',
#   'happy?',
#   'good',
#   'boy?',
#   'think',
#   'me?are',
#   'missing',
#   '?'],
#  ['customer',
#   'service',
#   'annoncement.',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'you.',
#   'please',
#   'call',
#   '07046744435',
#   'arrange',
#   'delivery'],
#  ['winner',
#   'u',
#   'specially',
#   'selected',
#   '2',
#   'receive',
#   '£1000',
#   'cash',
#   '4*',
#   'holiday',
#   '(flights',
#   'inc)',
#   'speak',
#   'live',
#   'operator',
#   '2',
#   'claim',
#   '0871277810810'],
#  ['keep',
#   'safe',
#   'need',
#   'miss',
#   'already',
#   'envy',
#   'everyone',
#   "see's",
#   'real',
#   'life'],
#  ['new', 'car', 'house', 'parents.:)i', 'new', 'job', 'hand:)'],
#  ["i'm",
#   'love',
#   'you.',
#   "i'm",
#   'excited',
#   'day',
#   'spend',
#   'you.',
#   'make',
#   'happy.'],
#  ['-pls',
#   'stop',
#   'bootydelious',
#   '(32/f)',
#   'inviting',
#   'friend.',
#   'reply',
#   'yes-434',
#   'no-434',
#   'see',
#   'her:',
#   'www.sms.ac/u/bootydelious',
#   'stop?',
#   'send',
#   'stop',
#   'frnd',
#   '62468'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'way.',
#   'u',
#   'receive',
#   'service',
#   'msg',
#   '2',
#   'download',
#   'ur',
#   'content.',
#   'u',
#   'not,',
#   'goto',
#   'wap.',
#   'bangb.',
#   'tv',
#   'ur',
#   'mobile',
#   'internet/service',
#   'menu'],
#  ['place', 'ur', 'point', 'e', 'culture', 'module', 'already.'],
#  ['urgent!',
#   'trying',
#   'contact',
#   'you.',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   '£900',
#   'prize',
#   'guaranteed.',
#   'call',
#   '09061701939.',
#   'claim',
#   'code',
#   's89.',
#   'valid',
#   '12hrs'],
#  ['hi',
#   'frnd,',
#   'best',
#   'way',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'beloved',
#   "one's?"],
#  ['great', 'escape.', 'fancy', 'bridge', 'need', 'lager.', 'see', 'tomo'],
#  ['yes', ':)it', 'completely', 'form:)clark', 'also', 'utter', 'waste.'],
#  ['sir,', 'need', 'axis', 'bank', 'account', 'bank', 'address.'],
#  ['hmmm..',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'hop',
#   'ard...',
#   'ya,',
#   'go',
#   '4',
#   'free',
#   'abt...',
#   'muz',
#   'call',
#   'u',
#   'discus',
#   'liao...'],
#  ['time', 'coming', 'later?'],
#  ['bloody',
#   'hell,',
#   'cant',
#   'believe',
#   'forgot',
#   'surname',
#   'mr',
#   '.',
#   'ill',
#   'give',
#   'u',
#   'clue,',
#   'spanish',
#   'begin',
#   'm...'],
#  ['well,', "i'm", 'gonna', 'finish', 'bath', 'now.', 'good...fine', 'night.'],
#  ['let', 'know', 'got', 'money', 'carlos', 'make', 'call'],
#  ['u', 'still', 'going', 'mall?'],
#  ['turn',
#   'friend',
#   'staying',
#   'whole',
#   'show',
#   'back',
#   'til',
#   '~',
#   '&lt;#&gt;',
#   ',',
#   'feel',
#   'free',
#   'go',
#   'ahead',
#   'smoke',
#   '$',
#   '&lt;#&gt;',
#   'worth'],
#  ['text', 'her.', 'doesnt', 'reply', 'let', 'know', 'log'],
#  ['hi!',
#   'spoke',
#   'maneesha',
#   'v.',
#   "we'd",
#   'like',
#   'know',
#   'satisfied',
#   'experience.',
#   'reply',
#   'toll',
#   'free',
#   'yes',
#   'no.'],
#  ['lifted',
#   'hope',
#   'offer',
#   'money.',
#   'need.',
#   'especially',
#   'end',
#   'month',
#   'approach',
#   'hurt',
#   'studying.',
#   'anyways',
#   'gr8',
#   'weekend'],
#  ['lol', 'no.', 'u', 'trust', 'me.'],
#  ['ok.', 'gentleman', 'treat', 'dignity', 'respect.'],
#  ['will,', 'guy', 'close?'],
#  ['going', 'nothing', 'great.bye'],
#  ['hello',
#   'handsome',
#   '!',
#   'finding',
#   'job',
#   '?',
#   'lazy',
#   '?',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'net',
#   'mummy',
#   '?',
#   "where's",
#   'boytoy',
#   '?',
#   'miss',
#   '?'],
#  ['haha', 'awesome,', 'minute'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'freephone',
#   '0808',
#   '145',
#   '4742',
#   '9am-11pm',
#   'guaranteed',
#   '£1000',
#   'cash',
#   '£5000',
#   'prize!'],
#  ['got', 'xmas', 'radio', 'times.', 'get'],
#  ['jus',
#   'reached',
#   'home.',
#   'go',
#   'bathe',
#   'first.',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'u',
#   'finish',
#   'k...'],
#  ['unique', 'enough?', 'find', '30th', 'august.', 'www.areyouunique.co.uk'],
#  ["i'm",
#   'sorry.',
#   "i've",
#   'joined',
#   'league',
#   'people',
#   'dont',
#   'keep',
#   'touch.',
#   'mean',
#   'great',
#   'deal',
#   'me.',
#   'friend',
#   'time',
#   'even',
#   'great',
#   'personal',
#   'cost.',
#   'great',
#   'week.|'],
#  ['hi', ':)finally', 'completed', 'course:)'],
#  ['stop',
#   'itself.',
#   'however',
#   'suggest',
#   'stay',
#   'someone',
#   'able',
#   'give',
#   'or',
#   'every',
#   'stool.'],
#  ['doing?',
#   'hope',
#   'settled',
#   'new',
#   'school',
#   'year.',
#   'wishin',
#   'gr8',
#   'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['u', 'got', 'person', 'story'],
#  ['hamster', 'dead?', 'hey', 'tmr', 'meet', '1pm', 'orchard', 'mrt?'],
#  ['hi',
#   'kate',
#   'evening?',
#   'hope',
#   'see',
#   'tomorrow',
#   'bit',
#   'bloody',
#   'babyjontet!',
#   'txt',
#   'back',
#   'u',
#   'can.',
#   ':)',
#   'xxx'],
#  ['found', 'it,', 'enc', '&lt;#&gt;', ',', 'at?'],
#  ['sent', '&lt;#&gt;', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'txt',
#   'u',
#   'finish',
#   'u',
#   'love',
#   'kate',
#   'xxx'],
#  ['account',
#   'refilled',
#   'successfully',
#   'inr',
#   '&lt;decimal&gt;',
#   '.',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'r',
#   '&lt;decimal&gt;',
#   '.',
#   'transaction',
#   'id',
#   'kr',
#   '&lt;#&gt;',
#   '.'],
#  ['goodmorning', 'sleeping', 'ga.'],
#  ['u', 'call', 'alter', '11', 'ok.'],
#  ['ü',
#   'say',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar...'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said,',
#   "''",
#   'happy',
#   "b'day",
#   'bos',
#   "!!''.",
#   'felt',
#   'special.',
#   'askd',
#   '4',
#   'lunch.',
#   'lunch',
#   'invited',
#   'apartment.',
#   'went',
#   'there.'],
#  ['aight', 'yo,', 'dat', 'straight', 'dogg'],
#  ['please',
#   'give',
#   'u',
#   'connection',
#   'today',
#   '&lt;decimal&gt;',
#   'refund',
#   'bill'],
#  [':)', 'shoot', 'big', 'load', 'get', 'ready!'],
#  ["what's", 'bruv,', 'hope', 'great', 'break.', 'rewarding', 'semester.'],
#  ['home', 'always', 'chat'],
#  ['k:)k:)good:)study', 'well.'],
#  ['yup...', 'ü', 'noe', 'leh...'],
#  ['sound', 'great!', 'home', 'now?'],
#  ['finally', 'match', 'heading', 'towards', 'draw', 'prediction.'],
#  ['tired.', 'slept', 'well', 'past', 'nights.'],
#  ['easy', 'ah?sen', 'got', 'selected', 'mean', 'good..'],
#  ['take', 'exam', 'march', '3'],
#  ['yeah',
#   'should.',
#   'think',
#   'use',
#   'gt',
#   'atm',
#   'register.',
#   'sure',
#   "there's",
#   'anyway',
#   'help',
#   'let',
#   'know.',
#   'sure',
#   'ready.'],
#  ['ok', 'prob.', 'take', 'ur', 'time.'],
#  ['o',
#   'called',
#   'ubandu',
#   'run',
#   'without',
#   'installing',
#   'hard',
#   'disk...you',
#   'use',
#   'o',
#   'copy',
#   'important',
#   'file',
#   'system',
#   'give',
#   'repair',
#   'shop..'],
#  ['sorry,', "i'll", 'call', 'later'],
#  ['u',
#   'say',
#   'leh...',
#   'course',
#   'nothing',
#   'happen',
#   'lar.',
#   'say',
#   'v',
#   'romantic',
#   'jus',
#   'bit',
#   'lor.',
#   'thk',
#   'e',
#   'nite',
#   'scenery',
#   'nice',
#   'leh.'],
#  ['500',
#   'new',
#   'mobile',
#   '2004,',
#   'must',
#   'go!',
#   'txt:',
#   'nokia',
#   'no:',
#   '89545',
#   '&',
#   'collect',
#   'today!from',
#   '£1',
#   'www.4-tc.biz',
#   '2optout',
#   '087187262701.50gbp/mtmsg18'],
#  ['would',
#   'really',
#   'appreciate',
#   'call',
#   'me.',
#   'need',
#   'someone',
#   'talk',
#   'to.'],
#  ['u',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon?',
#   'ur',
#   'career',
#   '2',
#   'flyng',
#   'start?',
#   '2',
#   'find',
#   'free,',
#   'txt',
#   'horo',
#   'followed',
#   'ur',
#   'star',
#   'sign,',
#   'e.',
#   'g.',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu.'],
#  ['life',
#   'strict',
#   'teacher...',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   '&amp;',
#   'conduct',
#   'exam,',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   '&amp;',
#   'teach',
#   'lessons.',
#   'happy',
#   'morning.',
#   '.',
#   '.'],
#  ['dear', 'good', 'morning'],
#  ['get',
#   'gandhipuram',
#   'walk',
#   'cross',
#   'cut',
#   'road.',
#   'right',
#   'side',
#   '&lt;#&gt;',
#   'street',
#   'road',
#   'turn',
#   'first',
#   'right.'],
#  ['dear', 'going', 'rubber', 'place'],
#  ['sorry', 'battery', 'died,', 'yeah', "i'm"],
#  ['yes:)here', 'tv', 'always', 'available', 'work', 'place..'],
#  ['text',
#   '&',
#   'meet',
#   'someone',
#   'sexy',
#   'today.',
#   'u',
#   'find',
#   'date',
#   'even',
#   'flirt',
#   'u.',
#   'join',
#   '4',
#   '10p.',
#   'reply',
#   'name',
#   '&',
#   'age',
#   'eg',
#   'sam',
#   '25.',
#   '18',
#   '-msg',
#   'recd@thirtyeight',
#   'penny'],
#  ['printed', 'oh.', '&lt;#&gt;', 'come', 'upstairs'],
#  ['ill', 'little', 'closer', 'like', 'bus', 'stop', 'street'],
#  ['you?when', 'wil', 'reach', 'here?'],
#  ['new',
#   'theory:',
#   'argument',
#   'win',
#   'situation,',
#   'loses',
#   'person.',
#   'dont',
#   'argue',
#   'ur',
#   'friend',
#   'just..',
#   '.',
#   '.',
#   '.',
#   'kick',
#   '&amp;',
#   'say,',
#   "i'm",
#   'always',
#   'correct.!'],
#  ['u',
#   '447801259231',
#   'secret',
#   'admirer',
#   'looking',
#   '2',
#   'make',
#   'contact',
#   'u-find',
#   'r*reveal',
#   'think',
#   'ur',
#   'special-call',
#   '09058094597'],
#  ['tomarrow', 'final', 'hearing', 'laptop', 'case', 'cant.'],
#  ['pleassssssseeeeee', 'tel', 'v', 'avent', 'done', 'sportsx'],
#  ['okay.', 'no,', 'shining', 'on.', 'meant', 'signing,', 'sound', 'better.'],
#  ['although',
#   'told',
#   'u',
#   'dat',
#   "i'm",
#   'baig',
#   'face',
#   'watch',
#   'really',
#   'like',
#   'e',
#   'watch',
#   'u',
#   'gave',
#   'co',
#   'fr',
#   'u.',
#   'thanx',
#   '4',
#   'everything',
#   'dat',
#   "u've",
#   'done',
#   'today,',
#   "i'm",
#   'touched...'],
#  ['u', 'remember', 'old', 'commercial?'],
#  ['late.', 'said', 'website.', 'dont', 'slipper'],
#  ['asked', 'call', 'ok'],
#  ['kallis', 'wont', 'bat', '2nd', 'innings.'],
#  ['didnt',
#   'work',
#   'oh.',
#   'ok',
#   'goodnight',
#   'then.',
#   'i.ll',
#   'fix',
#   'ready',
#   'time',
#   'wake',
#   'up.',
#   'dearly',
#   'missed',
#   'good',
#   'night',
#   'sleep.'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   '500',
#   'cd',
#   'voucher',
#   '125gift',
#   'guaranteed',
#   '&',
#   'free',
#   'entry',
#   '2',
#   '100',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   '87066',
#   'tncs',
#   'www.ldew.com1win150ppmx3age16'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'deepak', '5min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'u,',
#   'dnt',
#   'take',
#   'seriously..',
#   'coz',
#   'angry',
#   'childish',
#   'n',
#   'true',
#   'way',
#   'showing',
#   'deep',
#   'affection,',
#   'care',
#   'n',
#   'luv!..',
#   'kettoda',
#   'manda...',
#   'nice',
#   'day',
#   'da.'],
#  ['doing?how', 'you?'],
#  ['ups',
#   '3days',
#   'also,',
#   'shipping',
#   'company',
#   'take',
#   '2wks.',
#   'way',
#   'usps',
#   'take',
#   'week',
#   'get',
#   'lag',
#   'may',
#   'bribe',
#   'nipost',
#   'get',
#   'stuff.'],
#  ["i'm", 'back,', 'lemme', 'know', 'ready'],
#  ['necessarily', 'expect', 'done', 'get', 'back', 'though', "i'm", 'headin'],
#  ['mmm', 'yummy', 'babe', '...', 'nice', 'jolt', 'suzy'],
#  ['lover', '?', 'need', '...'],
#  ['tried',
#   'contact',
#   'reply',
#   'offer',
#   'video',
#   'handset?',
#   '750',
#   'anytime',
#   'network',
#   'mins?',
#   'unlimited',
#   'text?',
#   'camcorder?',
#   'reply',
#   'call',
#   '08000930705'],
#  ['i‘m', 'parked', 'next', 'mini!!!!', 'coming', 'today', 'think?'],
#  ['yup'],
#  ['anyway',
#   "i'm",
#   'going',
#   'shopping',
#   'now.',
#   'co',
#   'si',
#   'done',
#   'yet.',
#   'dun',
#   'disturb',
#   'u',
#   'liao.'],
#  ['no.', 'luton', '0125698789', 'ring', 'ur', 'around!', 'h*'],
#  ['hey',
#   'really',
#   'horny',
#   'want',
#   'chat',
#   'see',
#   'naked',
#   'text',
#   'hot',
#   '69698',
#   'text',
#   'charged',
#   '150pm',
#   'unsubscribe',
#   'text',
#   'stop',
#   '69698'],
#  ['dint', 'come', 'us.'],
#  ['same.', 'wana', 'plan', 'trip', 'sometme'],
#  ['sure', 'yet,', 'still', 'trying', 'get', 'hold'],
#  ['ur',
#   'ringtone',
#   'service',
#   'changed!',
#   '25',
#   'free',
#   'credits!',
#   'go',
#   'club4mobiles.com',
#   'choose',
#   'content',
#   'now!',
#   'stop?',
#   'txt',
#   'club',
#   'stop',
#   '87070.',
#   '150p/wk',
#   'club4',
#   'po',
#   'box1146',
#   'mk45',
#   '2wt'],
#  ['evo.', 'download', 'flash.', 'jealous?'],
#  ['ringtone',
#   'club:',
#   'get',
#   'uk',
#   'single',
#   'chart',
#   'mobile',
#   'week',
#   'choose',
#   'top',
#   'quality',
#   'ringtone!',
#   'message',
#   'free',
#   'charge.'],
#  ['come', 'mu,', "we're", 'sorting', 'narcotic', 'situation'],
#  ['night',
#   'ended',
#   'another',
#   'day,',
#   'morning',
#   'come',
#   'special',
#   'way.',
#   'may',
#   'smile',
#   'like',
#   'sunny',
#   'ray',
#   'leaf',
#   'worry',
#   'blue',
#   'blue',
#   'bay.'],
#  ['hmv',
#   'bonus',
#   'special',
#   '500',
#   'pound',
#   'genuine',
#   'hmv',
#   'voucher',
#   'won.',
#   'answer',
#   '4',
#   'easy',
#   'questions.',
#   'play',
#   'now!',
#   'send',
#   'hmv',
#   '86688',
#   'info:www.100percent-real.com'],
#  ['usf', 'guess,', 'might', 'well', 'take', '1', 'car'],
#  ['objection.', 'bf', 'coming.'],
#  ['thanx...'],
#  ['tell', 'rob', 'mack', 'gf', 'theater'],
#  ['awesome,', "i'll", 'see', 'bit'],
#  ['sent', 'it.', 'type', 'food', 'like?'],
#  ['done?', 'handed', 'in?', 'celebration', 'full', 'swing', 'yet?'],
#  ['got', 'called', 'tool?'],
#  ['wen',
#   'u',
#   'miss',
#   'someone,',
#   'person',
#   'definitely',
#   'special',
#   'u.....',
#   'person',
#   'special,',
#   'miss',
#   'them,',
#   'keep-in-touch',
#   'gdeve..'],
#  ['ok.', 'asked', 'money', 'far'],
#  ['okie...'],
#  ['yeah',
#   'think',
#   'usual',
#   "guy's",
#   'still',
#   'passed',
#   'last',
#   'night,',
#   'get',
#   'ahold',
#   'anybody',
#   'let',
#   'know',
#   "i'll",
#   'throw'],
#  ['k,', 'might', 'come', 'tonight', 'class', 'let', 'early'],
#  ['ok..'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'girl',
#   'friend',
#   'r',
#   'u',
#   '2?',
#   'give',
#   'call',
#   'hour',
#   'home',
#   'thats',
#   'alright',
#   'fone',
#   'fone',
#   'love',
#   'jenny',
#   'xxx'],
#  ['life',
#   'mean',
#   'lot',
#   'me,',
#   'love',
#   'life,',
#   'love',
#   'people',
#   'life,',
#   'world',
#   'call',
#   'friends,',
#   'call',
#   'world:-)..',
#   'ge:-)..'],
#  ['dear,shall',
#   'mail',
#   'tonite.busy',
#   'street,shall',
#   'update',
#   'tonite.things',
#   'looking',
#   'ok.varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu.but',
#   'good',
#   'one',
#   'real',
#   'sense.'],
#  ['hey', 'told', 'name', 'gautham', 'ah?'],
#  ['haf', 'u', 'found', 'him?', 'feel', 'stupid', 'da', 'v', 'cam', 'working.'],
#  ['oops.', '4', 'got', 'bit.'],
#  ['much', 'buzy'],
#  ['accidentally', 'deleted', 'message.', 'resend', 'please.'],
#  ['t-mobile',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   '&',
#   'pay',
#   '&',
#   'go',
#   'sim',
#   'card',
#   'loyalty.',
#   'call',
#   '0845',
#   '021',
#   '3680.offer',
#   'end',
#   "28thfeb.t&c's",
#   'apply'],
#  ['unless', 'situation', 'go', 'gurl', 'would', 'appropriate'],
#  ['hurt',
#   'me...',
#   'tease',
#   'me...',
#   'make',
#   'cry...',
#   'end',
#   'life',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'grave',
#   'say',
#   'stupid',
#   'miss',
#   'u..',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'phone', 'right', 'now.', 'pls', 'send', 'message'],
#  ['need', 'coffee', 'run', "tomo?can't", 'believe', 'time', 'week', 'already'],
#  ['awesome,',
#   'remember',
#   'last',
#   'time',
#   'got',
#   'somebody',
#   'high',
#   'first',
#   'time',
#   'diesel',
#   ':v'],
#  ['shit',
#   'really',
#   'shocking',
#   'scary,',
#   'cant',
#   'imagine',
#   'second.',
#   'def',
#   'night',
#   'out.',
#   'u',
#   'think',
#   'somewhere',
#   'could',
#   'crash',
#   'night,',
#   'save',
#   'taxi?'],
#  ['oh', 'way', 'food', 'fridge!', 'want', 'go', 'meal', 'tonight?'],
#  ['womdarfull', 'actor'],
#  ['sms.',
#   'ac',
#   'blind',
#   'date',
#   '4u!:',
#   'rodds1',
#   '21/m',
#   'aberdeen,',
#   'united',
#   'kingdom.',
#   'check',
#   'http://img.',
#   'sms.',
#   'ac/w/icmb3cktz8r7!-4',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup...', 'remb...', 'think', 'book...'],
#  ['jos', 'ask', 'u', 'wana', 'meet', 'up?'],
#  ['lol',
#   'yes.',
#   'friendship',
#   'hanging',
#   'thread',
#   'cause',
#   'u',
#   'buy',
#   'stuff.'],
#  ['themob>',
#   'check',
#   'newest',
#   'selection',
#   'content,',
#   'games,',
#   'tones,',
#   'gossip,',
#   'babe',
#   'sport,',
#   'keep',
#   'mobile',
#   'fit',
#   'funky',
#   'text',
#   'wap',
#   '82468'],
#  ['garage', 'keys?', 'bookshelf'],
#  ['today',
#   'accept',
#   'day..u',
#   'accept',
#   'as?',
#   'brother',
#   'sister',
#   'lover',
#   'dear1',
#   'best1',
#   'clos1',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   '?',
#   'win',
#   '£200',
#   'week',
#   'weekly',
#   'quiz,',
#   'text',
#   'play',
#   '85222',
#   'now!t&cs',
#   'winnersclub',
#   'po',
#   'box',
#   '84,',
#   'm26',
#   '3uz.',
#   '16+.',
#   'gbp1.50/week'],
#  ['say',
#   "he'll",
#   'give',
#   'call',
#   "friend's",
#   'got',
#   'money',
#   "he's",
#   'definitely',
#   'buying',
#   'end',
#   'week'],
#  ['hi',
#   'way',
#   'u',
#   '2day,',
#   'normal',
#   'way&this',
#   'real',
#   'me.',
#   'ur',
#   'unique&i',
#   'hope',
#   'know',
#   'u',
#   '4',
#   'rest',
#   'mylife.',
#   'hope',
#   'u',
#   'find',
#   'wot',
#   'lost.'],
#  ['made', 'day.', 'great', 'day', 'too.'],
#  ['k.k:)advance', 'happy', 'pongal.'],
#  ['hmmm...',
#   'guess',
#   'go',
#   '4',
#   'kb',
#   'n',
#   'power',
#   'yoga...',
#   'haha,',
#   'dunno',
#   'tahan',
#   'power',
#   'yoga',
#   'anot...',
#   'thk',
#   'got',
#   'lo',
#   'oso,',
#   'forgot',
#   'liao...'],
#  ['really', 'dude,', 'friend', "i'm", 'afraid', ':('],
#  ['december',
#   'only!',
#   'mobile',
#   '11mths+?',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'free!',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   '08002986906'],
#  ['coffee', 'cake,', 'guess...'],
#  ['merry', 'christmas', 'babe,', 'love', 'ya', '*kisses*'],
#  ['hey...', 'dont', 'go', 'watch', 'x', 'men', 'lunch...', 'haha'],
#  ['cud',
#   'u',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'b',
#   'bit',
#   'l8',
#   'co',
#   '2',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'full',
#   '&',
#   'im',
#   'still',
#   'waitin',
#   '4',
#   '1.',
#   'pete',
#   'x'],
#  ['would',
#   'great.',
#   "we'll",
#   'guild.',
#   'could',
#   'meet',
#   'bristol',
#   'road',
#   'somewhere',
#   '-',
#   'get',
#   'touch',
#   'weekend.',
#   'plan',
#   'take',
#   'flight!',
#   'good',
#   'week'],
#  ['problem.', 'doing?'],
#  ['calls..messages..missed', 'call'],
#  ['hi', 'da:)how', 'today', 'class?'],
#  ["i'd",
#   'say',
#   "that's",
#   'good',
#   'sign',
#   'but,',
#   'well,',
#   'know',
#   'track',
#   'record',
#   'reading',
#   'woman'],
#  ['cool,', 'text', 'parked'],
#  ["i'm", 'reading', 'text', 'sent', 'you.', 'meant', 'joke.', 'read', 'light'],
#  ['k.k:)apo', 'k.good', 'movie.'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'tomo',
#   'return',
#   'immediately',
#   '..?',
#   'something.'],
#  ['call',
#   'germany',
#   '1',
#   'penny',
#   'per',
#   'minute!',
#   'call',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   '0844',
#   '861',
#   '85',
#   '85.',
#   'prepayment.',
#   'direct',
#   'access!'],
#  ['chance',
#   'might',
#   'evaporated',
#   'soon',
#   'violated',
#   'privacy',
#   'stealing',
#   'phone',
#   'number',
#   "employer's",
#   'paperwork.',
#   'cool',
#   'all.',
#   'please',
#   'contact',
#   'report',
#   'supervisor.'],
#  ['valentine',
#   'day',
#   'special!',
#   'win',
#   '£1000',
#   'quiz',
#   'take',
#   'partner',
#   'trip',
#   'lifetime!',
#   'send',
#   'go',
#   '83600',
#   'now.',
#   '150p/msg',
#   'rcvd.',
#   'custcare:08718720201.'],
#  ['ta-daaaaa!', 'home', 'babe,', 'still', '?'],
#  ['cool.', 'come', 'havent', 'wined', 'dined', 'before?'],
#  ['sleeping..and', 'surfing'],
#  ['sorry,', "i'll", 'call', 'later'],
#  ['u', 'calling', 'right?', 'call', 'hand', 'phone...'],
#  ['ok', "that's", 'great', 'thanx', 'lot.'],
#  ['take',
#   'post',
#   'come',
#   'then!',
#   'must',
#   '1000',
#   'text',
#   'now!',
#   'happy',
#   'reading.',
#   'one',
#   'wiv',
#   'hello',
#   'caroline',
#   'end',
#   'favourite.',
#   'bless'],
#  ['u', 'hiding', 'stranger?'],
#  ['interested', 'like', 'that.'],
#  ['sister', 'cleared', 'two', 'round', 'birla', 'soft', 'yesterday.'],
#  ['gudnite....tc...practice', 'going'],
#  ['dis',
#   'yijue.',
#   'jus',
#   'saw',
#   'ur',
#   'mail.',
#   'case',
#   'huiming',
#   'havent',
#   'sent',
#   'u',
#   'num.',
#   'dis',
#   'num.'],
#  ['one', 'small', 'prestige', 'problem', 'now.'],
#  ['fancy',
#   'shag?',
#   'do.interested?',
#   'sextextuk.com',
#   'txt',
#   'xxuk',
#   'suzy',
#   '69876.',
#   'txts',
#   'cost',
#   '1.50',
#   'per',
#   'msg.',
#   'tncs',
#   'website.',
#   'x'],
#  ['checking',
#   'you.',
#   'really',
#   'miss',
#   'seeing',
#   'jeremiah.',
#   'great',
#   'month'],
#  ['nah', "can't", 'help', 'there,', "i've", 'never', 'iphone'],
#  ['car', 'hour', 'half', "i'm", 'going', 'apeshit'],
#  ['today',
#   'sorry',
#   'day.!',
#   'ever',
#   'angry',
#   'you,',
#   'ever',
#   'misbehaved',
#   'hurt',
#   'you?',
#   'plz',
#   'plz',
#   'slap',
#   'urself',
#   'bcoz,',
#   'ur',
#   'fault,',
#   "i'm",
#   'basically',
#   'good'],
#  ['yo',
#   'guy',
#   'ever',
#   'figure',
#   'much',
#   'need',
#   'alcohol?',
#   'jay',
#   'trying',
#   'figure',
#   'much',
#   'safely',
#   'spend',
#   'weed'],
#  ['&lt;#&gt;', 'ish', 'minute', '5', 'minute', 'ago.', 'wtf.'],
#  ['thank',
#   'calling.forgot',
#   'say',
#   'happy',
#   'onam',
#   'sirji.i',
#   'fine',
#   'remembered',
#   'met',
#   'insurance',
#   'person.meet',
#   'qatar',
#   'insha',
#   'allah.rakhesh,',
#   'ex',
#   'tata',
#   'aig',
#   'joined',
#   'tissco,tayseer.'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   '500',
#   'cd',
#   'voucher',
#   '125gift',
#   'guaranteed',
#   '&',
#   'free',
#   'entry',
#   '2',
#   '100',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   '87066',
#   'tncs',
#   'www.ldew.com1win150ppmx3age16'],
#  ['ur',
#   'cash-balance',
#   'currently',
#   '500',
#   'pound',
#   '-',
#   'maximize',
#   'ur',
#   'cash-in',
#   'send',
#   'cash',
#   '86688',
#   '150p/msg.',
#   'cc:',
#   '08708800282',
#   'hg/suite342/2lands',
#   'row/w1j6hl'],
#  ["i'm",
#   'actor.',
#   'work,',
#   'work',
#   'evening',
#   'sleep',
#   'late.',
#   'since',
#   "i'm",
#   'unemployed',
#   'moment,',
#   'always',
#   'sleep',
#   'late.',
#   'unemployed,',
#   'every',
#   'day',
#   'saturday.'],
#  ['hello!',
#   'got',
#   'here,',
#   'st',
#   'andrews-boy',
#   'long',
#   'way!',
#   'cold.',
#   'keep',
#   'posted'],
#  ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikku:-):-db-)'],
#  ['oh', 'ok', 'prob..'],
#  ['check', "audrey's", 'status', 'right'],
#  ['busy',
#   'here.',
#   'trying',
#   'finish',
#   'new',
#   'year.',
#   'looking',
#   'forward',
#   'finally',
#   'meeting',
#   'you...'],
#  ['good',
#   'afternoon',
#   'sunshine!',
#   'dawn',
#   'day',
#   '?',
#   'refreshed',
#   'happy',
#   'alive?',
#   'breathe',
#   'air',
#   'smile',
#   '?',
#   'think',
#   'you,',
#   'love',
#   '...',
#   'always'],
#  ['well', 'know', 'z', 'take', 'care', 'me.', 'worries.'],
#  ['update_now',
#   '-',
#   'xmas',
#   'offer!',
#   'latest',
#   'motorola,',
#   'sonyericsson',
#   '&',
#   'nokia',
#   '&',
#   'free',
#   'bluetooth!',
#   'double',
#   'min',
#   '&',
#   '1000',
#   'txt',
#   'orange.',
#   'call',
#   'mobileupd8',
#   '08000839402',
#   'call2optout/f4q='],
#  ['discount',
#   'code',
#   'rp176781.',
#   'stop',
#   'message',
#   'reply',
#   'stop.',
#   'www.regalportfolio.co.uk.',
#   'customer',
#   'service',
#   '08717205546'],
#  ['wat', 'uniform?', 'get?'],
#  ['cool,', 'text', 'ready'],
#  ['hello',
#   'boytoy',
#   '...',
#   'geeee',
#   'miss',
#   'already',
#   'woke',
#   'up.',
#   'wish',
#   'bed',
#   'me,',
#   'cuddling',
#   'me.',
#   'love',
#   '...'],
#  ['spoil', 'bed', 'well', ':)'],
#  ["i'm", 'going', 'bath', 'msg', 'next', '&lt;#&gt;', 'min..'],
#  ['cant',
#   'keep',
#   'talking',
#   'people',
#   'sure',
#   'pay',
#   'agree',
#   'price.',
#   'pls',
#   'tell',
#   'want',
#   'really',
#   'buy',
#   'much',
#   'willing',
#   'pay'],
#  ['thanks',
#   'ringtone',
#   'order,',
#   'reference',
#   't91.',
#   'charged',
#   'gbp',
#   '4',
#   'per',
#   'week.',
#   'unsubscribe',
#   'anytime',
#   'calling',
#   'customer',
#   'service',
#   '09057039994'],
#  ['say', 'happen'],
#  ['could', 'seen', 'me..i', "did't", 'recognise', 'face.:)'],
#  ['well',
#   "there's",
#   'lot',
#   'thing',
#   'happening',
#   'lindsay',
#   'new',
#   'year',
#   '*sighs*',
#   'bar',
#   'ptbo',
#   'blue',
#   'heron',
#   'something',
#   'going'],
#  ['keep', 'payasam', 'rinu', 'brings'],
#  ['taught',
#   'ranjith',
#   'sir',
#   'called',
#   'me.',
#   'sm',
#   'like',
#   'that.',
#   'becaus',
#   'he',
#   'verifying',
#   'project.',
#   'prabu',
#   'told',
#   'today',
#   'pa',
#   'dont',
#   'mistake',
#   'me..'],
#  ['guess',
#   "that's",
#   'worried.',
#   'must',
#   'know',
#   "there's",
#   'way',
#   'body',
#   'repair',
#   'itself.',
#   "i'm",
#   'quite',
#   'sure',
#   'worry.',
#   "we'll",
#   'take',
#   'slow.',
#   'first',
#   'tests,',
#   'guide',
#   'ovulation',
#   'relax.',
#   'nothing',
#   'said',
#   'reason',
#   'worry',
#   'i.ll',
#   'keep',
#   'followin',
#   'up.'],
#  ['yeah', 'sure,', 'give', 'couple', 'minute', 'track', 'wallet'],
#  ['hey', 'leave', 'it.', 'big', 'deal:-)', 'take', 'care.'],
#  ['hey', 'late', 'ah...', 'meet', '945+'],
#  ['double',
#   'min',
#   'txts',
#   '4',
#   '6months',
#   'free',
#   'bluetooth',
#   'orange.',
#   'available',
#   'sony,',
#   'nokia',
#   'motorola',
#   'phones.',
#   'call',
#   'mobileupd8',
#   '08000839402',
#   'call2optout/n9dx'],
#  ['took', 'mr', 'owl', '3', 'lick'],
#  ['customer', 'place', 'call', 'you.'],
#  ['mm', 'time', 'dont', 'like', 'fun'],
#  ['4mths',
#   'half',
#   'price',
#   'orange',
#   'line',
#   'rental',
#   '&',
#   'latest',
#   'camera',
#   'phone',
#   '4',
#   'free.',
#   'phone',
#   '11mths',
#   '?',
#   'call',
#   'mobilesdirect',
#   'free',
#   '08000938767',
#   'update',
#   'now!',
#   'or2stoptxt'],
#  ['yup', 'lunch', 'buffet', 'now..', 'u', 'eat', 'already?'],
#  ['huh', 'late...', 'fr', 'dinner?'],
#  ['hey', 'sat', 'going', 'intro', 'pilate', 'only?', 'kickboxing', 'too?'],
#  ['morning', 'ok.'],
#  ['yes',
#   'think',
#   'so.',
#   'office',
#   'lap',
#   'room',
#   'think',
#   'thats',
#   'last',
#   'days.',
#   'didnt',
#   'shut'],
#  ['pick', 'bout', '7.30ish?', 'time', 'going?'],
#  ['performance',
#   'award',
#   'calculated',
#   'every',
#   'two',
#   'month.not',
#   'current',
#   'one',
#   'month',
#   'period..'],
#  ['actually',
#   'sleeping',
#   'still',
#   'might',
#   'u',
#   'call',
#   'back.',
#   'text',
#   'gr8.',
#   'rock',
#   'sis.',
#   'send',
#   'u',
#   'text',
#   'wen',
#   'wake.'],
#  ['always',
#   'putting',
#   'business',
#   'there.',
#   'put',
#   'picture',
#   'as',
#   'facebook.',
#   'one',
#   'open',
#   'people',
#   "i've",
#   'ever',
#   'met.',
#   'would',
#   'think',
#   'picture',
#   'room',
#   'would',
#   'hurt',
#   'you,',
#   'make',
#   'feel',
#   'violated.'],
#  ['good',
#   'evening',
#   'sir,',
#   'al',
#   'salam',
#   'wahleykkum.sharing',
#   'happy',
#   'news.by',
#   'grace',
#   'god,',
#   'got',
#   'offer',
#   'tayseer,tissco',
#   'joined.hope',
#   'fine.inshah',
#   'allah,meet',
#   'sometime.rakhesh,visitor',
#   'india.'],
#  ['hmmm...k...but',
#   'want',
#   'change',
#   'field',
#   'quickly',
#   'da:-)i',
#   'wanna',
#   'get',
#   'system',
#   'administrator',
#   'network',
#   'administrator..'],
#  ['free',
#   'ringtone',
#   'text',
#   'first',
#   '87131',
#   'poly',
#   'text',
#   'get',
#   '87131',
#   'true',
#   'tone!',
#   'help?',
#   '0845',
#   '2814032',
#   '16',
#   '1st',
#   'free,',
#   'tone',
#   '3x£150pw',
#   'e£nd',
#   'txt',
#   'stop'],
#  ['dear', 'chechi.', 'talk'],
#  ['hair', 'cream', 'shipped.'],
#  ['none', "that's", 'happening', 'til', 'get', 'though'],
#  ['yep,',
#   'great',
#   'loxahatchee',
#   'xmas',
#   'tree',
#   'burning',
#   '&lt;#&gt;',
#   'start',
#   'hour'],
#  ['haha', 'get', 'used', 'driving', 'usf', 'man,', 'know', 'lot', 'stoner'],
#  ['well',
#   'slightly',
#   'disastrous',
#   'class',
#   'pm',
#   'fav',
#   'darlings!',
#   'hope',
#   'day',
#   'ok.',
#   'coffee',
#   'wld',
#   'good',
#   "can't",
#   'stay',
#   'late',
#   'tomorrow.',
#   'time',
#   '+',
#   'place',
#   'always?'],
#  ['hello!', 'good', 'week?', 'fancy', 'drink', 'something', 'later?'],
#  ['headin', 'towards', 'busetop'],
#  ['message:some',
#   'text',
#   'missing*',
#   'sender:name',
#   'missing*',
#   '*number',
#   'missing',
#   '*sent:date',
#   'missing',
#   '*missing',
#   'u',
#   'lot',
#   'thats',
#   'everything',
#   'missing',
#   'sent',
#   'via',
#   'fullonsms.com'],
#  ['come', 'room', 'point', 'iron', 'plan', 'weekend'],
#  ['co', 'want', 'thing'],
#  ['okies...',
#   "i'll",
#   'go',
#   'yan',
#   'jiu',
#   'too...',
#   'skip',
#   'ard',
#   'oso,',
#   'go',
#   'cine',
#   'den',
#   'go',
#   'mrt',
#   'one,',
#   'blah',
#   'blah',
#   'blah...'],
#  ['bring', 'home', 'wendy', '=d'],
#  ['100', 'dating', 'service', 'cal;l', '09064012103', 'box334sk38ch'],
#  ['whatsup', 'there.', 'dont', 'u', 'want', 'sleep'],
#  ['alright', 'new', 'goal'],
#  ['free',
#   'entry',
#   '£250',
#   'weekly',
#   'competition',
#   'text',
#   'word',
#   'win',
#   '80086',
#   'now.',
#   '18',
#   't&c',
#   'www.txttowin.co.uk'],
#  ['alright,', "i'll", 'head', 'minutes,', 'text', 'meet'],
#  ['send',
#   'logo',
#   '2',
#   'ur',
#   'lover',
#   '-',
#   '2',
#   'name',
#   'joined',
#   'heart.',
#   'txt',
#   'love',
#   'name1',
#   'name2',
#   'mobno',
#   'eg',
#   'love',
#   'adam',
#   'eve',
#   '07123456789',
#   '87077',
#   'yahoo!',
#   'pobox36504w45wq',
#   'txtno',
#   '4',
#   'ad',
#   '150p'],
#  ['yes:)from', 'last', 'week', "i'm", 'taking', 'live', 'call.'],
#  ['someone',
#   'contacted',
#   'dating',
#   'service',
#   'entered',
#   'phone',
#   'fancy',
#   'you!',
#   'find',
#   'call',
#   'landline',
#   '09111032124',
#   '.',
#   'pobox12n146tf150p'],
#  ['siva', 'hostel', 'aha:-.'],
#  ['urgent!',
#   'mobile',
#   'number',
#   'awarded',
#   '£2000',
#   'prize',
#   'guaranteed.',
#   'call',
#   '09058094455',
#   'land',
#   'line.',
#   'claim',
#   '3030.',
#   'valid',
#   '12hrs'],
#  ['send',
#   'ur',
#   'friend',
#   'receive',
#   'something',
#   'ur',
#   'voice.....',
#   'speaking',
#   'expression?',
#   '1.childish',
#   '2.naughty',
#   '3.sentiment',
#   '4.rowdy',
#   '5.ful',
#   'attitude',
#   '6.romantic',
#   '7.shy',
#   '8.attractive',
#   '9.funny',
#   '&lt;#&gt;',
#   '.irritating',
#   '&lt;#&gt;',
#   '.lovable.',
#   'reply',
#   'me..'],
#  ['ok.', "she'll", 'ok.', 'guess'],
#  ['aathi..where', 'dear..'],
#  ['pain', 'urination', 'thing', 'else?'],
#  ['7',
#   'esplanade..',
#   'ü',
#   'mind',
#   'giving',
#   'lift',
#   'co',
#   'got',
#   'car',
#   'today..'],
#  ['wnt',
#   'buy',
#   'bmw',
#   'car',
#   'urgently..its',
#   'vry',
#   'urgent.but',
#   'hv',
#   'shortage',
#   '&lt;#&gt;',
#   'lacs.there',
#   'source',
#   'arng',
#   'dis',
#   'amt.',
#   '&lt;#&gt;',
#   'lacs..thats',
#   'prob'],
#  ['home', 'watching', 'tv', 'lor.'],
#  ['usually',
#   'take',
#   'fifteen',
#   'fucking',
#   'minute',
#   'respond',
#   'yes',
#   'question'],
#  ['congrats!',
#   'nokia',
#   '3650',
#   'video',
#   'camera',
#   'phone',
#   'call',
#   '09066382422',
#   'call',
#   'cost',
#   '150ppm',
#   'ave',
#   'call',
#   '3mins',
#   'vary',
#   'mobile',
#   '16+',
#   'close',
#   '300603',
#   'post',
#   'bcm4284',
#   'ldn',
#   'wc1n3xx'],
#  ['booked', 'ticket', 'pongal?'],
#  ['available',
#   'now?',
#   "i'm",
#   'like',
#   'right',
#   'around',
#   'hillsborough',
#   '&amp;',
#   '&lt;#&gt;',
#   'th'],
#  ['message',
#   'sent',
#   'askin',
#   '&lt;#&gt;',
#   'dollars.',
#   'shoul',
#   'pay',
#   '&lt;#&gt;',
#   '&lt;#&gt;',
#   '?'],
#  ['ask',
#   'g',
#   'iouri,',
#   "i've",
#   'told',
#   'story',
#   'like',
#   'ten',
#   'time',
#   'already'],
#  ['long', 'applebees', 'fucking', 'take'],
#  ['hi',
#   'hope',
#   'u',
#   'get',
#   'txt~journey',
#   'hasnt',
#   'gd,now',
#   '50',
#   'min',
#   'late',
#   'think.'],
#  ['to.', 'like', 'love', 'arrange.'],
# ...
#  ['da', 'run', 'activate', 'full', 'version', 'da.'],
#  ['ah',
#   'poor',
#   'baby!hope',
#   'urfeeling',
#   'bettersn',
#   'luv!',
#   'probthat',
#   'overdose',
#   'work',
#   'hey',
#   'go',
#   'careful',
#   'spk',
#   '2',
#   'u',
#   'sn',
#   'lot',
#   'lovejen',
#   'xxx.'],
#  ['stop',
#   'story.',
#   "i've",
#   'told',
#   "i've",
#   'returned',
#   "he's",
#   'saying',
#   'order',
#   'it.'],
#  ['talk',
#   'sexy!!',
#   'make',
#   'new',
#   'friend',
#   'fall',
#   'love',
#   'world',
#   'discreet',
#   'text',
#   'dating',
#   'service.',
#   'text',
#   'vip',
#   '83110',
#   'see',
#   'could',
#   'meet.'],
#  ['going', 'take', 'babe', '?'],
#  ['hai',
#   'ana',
#   'tomarrow',
#   'coming',
#   'morning.',
#   '&lt;decimal&gt;',
#   'ill',
#   'sathy',
#   'go',
#   'rto',
#   'office.',
#   'reply',
#   'came',
#   'home.'],
#  ['spoon', 'okay?'],
#  ['say', 'somebody', 'named', 'tampa'],
#  ['work', 'now.', 'going', 'min.'],
#  ['brother', 'genius'],
#  ['sorry,',
#   'guess',
#   'whenever',
#   'get',
#   'hold',
#   'connections,',
#   'maybe',
#   'hour',
#   'two?',
#   "i'll",
#   'text'],
#  ['u', 'find', 'time', 'bus', 'coz', 'need', 'sort', 'stuff', 'out.'],
#  ['dude', 'ive', 'seeing', 'lotta', 'corvette', 'lately'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'either',
#   'yr',
#   'supply',
#   'cd',
#   'virgin',
#   'record',
#   'mystery',
#   'gift',
#   'guaranteed',
#   'call',
#   '09061104283',
#   'ts&cs',
#   'www.smsco.net',
#   '£1.50pm',
#   'approx',
#   '3mins'],
#  ['here,',
#   'consider',
#   'wall',
#   'bunker',
#   'shit',
#   'important',
#   'never',
#   'play',
#   'peaceful',
#   'guess',
#   'place',
#   'high',
#   'enough',
#   'matter'],
#  ['private!',
#   '2003',
#   'account',
#   'statement',
#   '07808',
#   'xxxxxx',
#   'show',
#   '800',
#   'un-redeemed',
#   's.',
#   'i.',
#   'm.',
#   'points.',
#   'call',
#   '08719899217',
#   'identifier',
#   'code:',
#   '41685',
#   'expires',
#   '07/11/04'],
#  ['hello.',
#   'need',
#   'posh',
#   'bird',
#   'chap',
#   'user',
#   'trial',
#   'prod',
#   'champneys.',
#   'put',
#   'down?',
#   'need',
#   'address',
#   'dob',
#   'asap.',
#   'ta',
#   'r'],
#  ['u',
#   'want',
#   'xmas?',
#   '100',
#   'free',
#   'text',
#   'message',
#   '&',
#   'new',
#   'video',
#   'phone',
#   'half',
#   'price',
#   'line',
#   'rental?',
#   'call',
#   'free',
#   '0800',
#   '0721072',
#   'find',
#   'more!'],
#  ['well',
#   'officially',
#   'philosophical',
#   'hole,',
#   'u',
#   'wanna',
#   'call',
#   'home',
#   'ready',
#   'saved!'],
#  ['going',
#   'good...no',
#   'problem..but',
#   'still',
#   'need',
#   'little',
#   'experience',
#   'understand',
#   'american',
#   'customer',
#   'voice...'],
#  ["i'll", 'text', 'drop', 'x'],
#  ['ugh', 'long', 'day.', "i'm", 'exhausted.', 'want', 'cuddle', 'take', 'nap'],
#  ['talk',
#   'atleast',
#   'day...!!!',
#   'otherwise',
#   'miss',
#   'best',
#   'friend',
#   'world...!!!',
#   '-shakespeare-',
#   'shesil',
#   '&lt;#&gt;'],
#  ['shop',
#   'till',
#   'u',
#   'drop,',
#   'you,',
#   'either',
#   '10k,',
#   '5k,',
#   '£500',
#   'cash',
#   '£100',
#   'travel',
#   'voucher,',
#   'call',
#   'now,',
#   '09064011000.',
#   'ntt',
#   'po',
#   'box',
#   'cr01327bt',
#   'fixedline',
#   'cost',
#   '150ppm',
#   'mobile',
#   'vary'],
#  ['castor?', 'need', 'see', 'something'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'q!',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'u',
#   'know',
#   'country',
#   'liverpool',
#   'played',
#   'mid',
#   'week?',
#   'txt',
#   'ansr',
#   '82277.',
#   '£1.50',
#   'sp:tyrone'],
#  ['u',
#   'secret',
#   'admirer',
#   'looking',
#   '2',
#   'make',
#   'contact',
#   'u-find',
#   'r*reveal',
#   'think',
#   'ur',
#   'special-call',
#   '09058094565'],
#  ['u',
#   'secret',
#   'admirer',
#   'looking',
#   '2',
#   'make',
#   'contact',
#   'u-find',
#   'r*reveal',
#   'think',
#   'ur',
#   'special-call',
#   '09065171142-stopsms-08'],
#  ['reminder:',
#   'downloaded',
#   'content',
#   'already',
#   'paid',
#   'for.',
#   'goto',
#   'http://doit.',
#   'mymoby.',
#   'tv/',
#   'collect',
#   'content.'],
#  ['see,',
#   'knew',
#   'giving',
#   'break',
#   'time',
#   'woul',
#   'lead',
#   'always',
#   'wanting',
#   'miss',
#   'curfew.',
#   'gonna',
#   'gibe',
#   "'til",
#   'one,',
#   'midnight',
#   'movie',
#   'gonna',
#   'get',
#   'til',
#   '2.',
#   'need',
#   'come',
#   'home.',
#   'need',
#   'getsleep',
#   'and,',
#   'anything,',
#   'need',
#   'b',
#   'studdying',
#   'ear',
#   'training.'],
#  ['love',
#   'give',
#   'massages.',
#   'use',
#   'lot',
#   'baby',
#   'oil...',
#   'fave',
#   'position?'],
#  ['dude', 'go', 'sup'],
#  ['yoyyooo',
#   'u',
#   'know',
#   'change',
#   'permission',
#   'drive',
#   'mac.',
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold.mike', 'hussey'],
#  ['like', 'talk', 'pa', 'able', 'to.', 'dont', 'know', 'y.'],
#  ['dun',
#   'cut',
#   'short',
#   'leh.',
#   'u',
#   'dun',
#   'like',
#   'ah?',
#   'failed.',
#   'quite',
#   'sad.'],
#  ['unbelievable', 'faglord'],
#  ['wife.how', 'knew', 'time', 'murder', 'exactly'],
#  ['ask', 'princess?'],
#  ['great', 'princess!', 'thinking', 'me?', ':)'],
#  ['nutter.',
#   'cutter.',
#   'ctter.',
#   'cttergg.',
#   'cttargg.',
#   'ctargg.',
#   'ctagg.',
#   'ie'],
#  ['ok',
#   'noe',
#   "u're",
#   'busy',
#   "i'm",
#   'really',
#   'bored',
#   'msg',
#   'u.',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'choose',
#   '4',
#   'one.'],
#  ['g', 'class', 'early', 'tomorrow', 'thus', 'trying', 'smoke', '&lt;#&gt;'],
#  ['superb',
#   'thought-',
#   '"be',
#   'grateful',
#   'u',
#   'dont',
#   'everything',
#   'u',
#   'want.',
#   'mean',
#   'u',
#   'still',
#   'opportunity',
#   'happier',
#   'tomorrow',
#   'u',
#   'today.":-)'],
#  ['hope', 'good', 'week.', 'checking'],
#  ["i'm",
#   'used',
#   'it.',
#   'hope',
#   'agent',
#   'drop',
#   'since',
#   "i've",
#   'booked',
#   'thing',
#   'year.',
#   'whole',
#   'boston,',
#   'nyc',
#   'experiment.'],
#  ['thursday', 'night?', 'yeah,', 'sure', 'thing,', "we'll", 'work'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected.',
#   'simply',
#   'text',
#   'password',
#   '"mix"',
#   '85069',
#   'verify.',
#   'get',
#   'usher',
#   'britney.',
#   'fml,',
#   'po',
#   'box',
#   '5249,',
#   'mk17',
#   '92h.',
#   '450ppw',
#   '16'],
#  ['probably',
#   'money',
#   'worries.',
#   'thing',
#   'coming',
#   'due',
#   'several',
#   'outstanding',
#   'invoice',
#   'work',
#   'two',
#   'three',
#   'month',
#   'ago.'],
#  ['possible', 'teach', 'you.', 'where.'],
#  ['wonder',
#   'phone',
#   'battery',
#   'went',
#   'dead',
#   '?',
#   'tell',
#   'you,',
#   'love',
#   'babe'],
#  ['lovely', 'smell', 'bus', "ain't", 'tobacco...'],
#  ["we're",
#   'getting',
#   'worried',
#   'here,',
#   'derek',
#   'taylor',
#   'already',
#   'assumed',
#   'worst'],
#  ['hey', "what's", 'charles', 'sorry', 'late', 'reply.'],
#  ['lastest',
#   'stereophonics,',
#   'marley,',
#   'dizzee',
#   'racal,',
#   'libertine',
#   'strokes!',
#   'win',
#   'nookii',
#   'game',
#   'flirt!!',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'text',
#   'wap',
#   '82468'],
#  ['i.ll',
#   'give',
#   'it.',
#   'plus',
#   'said',
#   'grinule',
#   'greet',
#   'whenever',
#   'speak'],
#  ['white', 'fudge', 'oreo', 'store'],
#  ['january',
#   'male',
#   'sale!',
#   'hot',
#   'gay',
#   'chat',
#   'cheaper,',
#   'call',
#   '08709222922.',
#   'national',
#   'rate',
#   '1.5p/min',
#   'cheap',
#   '7.8p/min',
#   'peak!',
#   'stop',
#   'text',
#   'call',
#   '08712460324',
#   '(10p/min)'],
#  ['love',
#   '!',
#   'come',
#   'took',
#   'long',
#   'leave',
#   "zaher's?",
#   'got',
#   'word',
#   'ym',
#   'happy',
#   'see',
#   'sad',
#   'left.',
#   'miss'],
#  ['sorry', 'hurt', 'you.'],
#  ["can't.",
#   'feel',
#   'nauseous.',
#   "i'm",
#   'pissed.',
#   'eat',
#   'sweet',
#   'week',
#   'cause',
#   'today',
#   'planning',
#   'pig',
#   'out.',
#   'dieting',
#   'week.',
#   "i'm",
#   'hungry',
#   ':/'],
#  ['ok', 'lor', 'early.', 'still', 'project', 'meeting', 'now.'],
#  ['call', 'da,', 'waiting', 'call.'],
#  ['could', 'ask', 'carlos', 'could', 'get', 'anybody', 'else', 'chip'],
#  ['actually', 'send', 'reminder', 'today.', 'wonderful', 'weekend'],
#  ['people',
#   'see',
#   'msgs,',
#   'think',
#   'iam',
#   'addicted',
#   'msging...',
#   'wrong,',
#   'bcoz',
#   "don\\'t",
#   'know',
#   'iam',
#   'addicted',
#   'sweet',
#   'friends..!!',
#   'bslvyl'],
#  ['hey',
#   'gave',
#   'photo',
#   'registered',
#   'driving',
#   'ah?',
#   'tmr',
#   'wanna',
#   'meet',
#   'yck?'],
#  ['dont', 'talk', 'ever', 'ok', 'word.'],
#  ['u', 'wana', 'see'],
#  ['way', 'school.', 'pls', 'send', "ashley's", 'number'],
#  ['shall', 'fine.', 'avalarr', 'now.', 'hollalater'],
#  ['went',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today..but',
#   'still',
#   "did't",
#   'reach',
#   'home..'],
#  ['actually',
#   'deleted',
#   'old',
#   'website..now',
#   'blogging',
#   'magicalsongs.blogspot.com'],
#  ['k,', 'wait', 'chikku..il', 'send', 'aftr', '&lt;#&gt;', 'min'],
#  ["i'm",
#   'diet.',
#   'ate',
#   '1',
#   'many',
#   'slice',
#   'pizza',
#   'yesterday.',
#   'ugh',
#   "i'm",
#   'always',
#   'diet.'],
#  ['k:)i', 'give', 'kvb', 'acc', 'details:)'],
#  ['oh', 'come', 'ah?'],
#  ['money!!!',
#   'r',
#   'lucky',
#   'winner',
#   '!',
#   '2',
#   'claim',
#   'prize',
#   'text',
#   'money',
#   '2',
#   '88600',
#   '£1million',
#   'give',
#   'away',
#   '!',
#   'ppt150x3+normal',
#   'text',
#   'rate',
#   'box403',
#   'w1t1jy'],
#  ["i'm",
#   'really',
#   'sorry',
#   'b',
#   'able',
#   '2',
#   'friday.hope',
#   'u',
#   'find',
#   'alternative.hope',
#   'yr',
#   "term's",
#   'going',
#   'ok:-)'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   'wa.',
#   'enjoy',
#   'wish',
#   'many',
#   'happy',
#   'moment',
#   'fro',
#   'wherever',
#   'go'],
#  ['samus', 'shoulder', 'yet'],
#  ['time', 'think', 'it?', 'need', 'know', 'near', 'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   '09063440451',
#   'landline,',
#   'complimentary',
#   '4*lux',
#   'tenerife',
#   'holiday',
#   '£1000',
#   'cash',
#   'await',
#   'collection.',
#   'ppm150',
#   'sae',
#   't&cs',
#   'box334',
#   'sk38xh.'],
#  ['dun', 'wear', 'jean', 'lor...'],
#  ['since', 'when,', 'side,', 'fever,', 'vomitin.'],
#  ['k:)k.are', 'college?'],
#  ['urgent!',
#   'call',
#   '09061749602',
#   'landline.',
#   'complimentary',
#   '4*',
#   'tenerife',
#   'holiday',
#   '£10,000',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   't&cs',
#   'box',
#   '528',
#   'hp20',
#   '1yf',
#   '150ppm',
#   '18+'],
#  ['better.',
#   'made',
#   'friday',
#   'stuffed',
#   'like',
#   'pig',
#   'yesterday.',
#   'feel',
#   'bleh.',
#   'least',
#   'writhing',
#   'pain',
#   'kind',
#   'bleh.'],
#  ['sell',
#   "we'll",
#   'ton',
#   'coins.',
#   'sell',
#   'coin',
#   'someone',
#   'thru',
#   'paypal.',
#   'voila!',
#   'money',
#   'back',
#   'life',
#   'pockets:)'],
#  ['theyre', 'lot', 'places.', 'hospital', 'medical', 'place', 'safe.'],
#  ['getting',
#   'touch',
#   'folk',
#   'waiting',
#   'company?',
#   'txt',
#   'back',
#   'name',
#   'age',
#   'opt',
#   'in!',
#   'enjoy',
#   'community',
#   '(150p/sms)'],
#  ['also',
#   "i've",
#   'sorta',
#   'blown',
#   'couple',
#   'time',
#   'recently',
#   'id',
#   'rather',
#   'text',
#   'blue',
#   'looking',
#   'weed'],
#  ['sent',
#   'score',
#   'sophas',
#   'secondary',
#   'application',
#   'schools.',
#   'think',
#   'thinking',
#   'applying,',
#   'research',
#   'cost',
#   'also.',
#   'contact',
#   'joke',
#   'ogunrinde,',
#   'school',
#   'one',
#   'less',
#   'expensive',
#   'one'],
#  ['cant', 'wait', 'see', 'you!', 'photo', 'useful?', ':)'],
#  ['ur',
#   'cash-balance',
#   'currently',
#   '500',
#   'pound',
#   '-',
#   'maximize',
#   'ur',
#   'cash-in',
#   'send',
#   'go',
#   '86688',
#   '150p/msg.',
#   'cc:',
#   '08718720201',
#   'po',
#   'box',
#   '114/14',
#   'tcr/w1'],
#  ['hey',
#   'booked',
#   'kb',
#   'sat',
#   'already...',
#   'lesson',
#   'going',
#   'ah?',
#   'keep',
#   'sat',
#   'night',
#   'free',
#   'need',
#   'meet',
#   'confirm',
#   'lodging'],
#  ['chk', 'ur', 'belovd', 'm', 'dict'],
#  ['time', 'want', 'come?'],
#  ['awesome,', 'lemme', 'know', 'whenever', 'around'],
#  ['shb', 'b', 'ok', 'lor...', 'thanx...'],
#  ['beautiful',
#   'truth',
#   'gravity..',
#   'read',
#   'carefully:',
#   '"our',
#   'heart',
#   'feel',
#   'light',
#   'someone',
#   'it..',
#   'feel',
#   'heavy',
#   'someone',
#   'leaf',
#   'it.."',
#   'good',
#   'night'],
#  ['also', 'remember', 'get', "dobby's", 'bowl', 'car'],
#  ['filthy', 'story', 'girl', 'waiting'],
#  ['sorry',
#   'c',
#   'ur',
#   'msg...',
#   'yar',
#   'lor',
#   'poor',
#   'thing...',
#   '4',
#   'one',
#   'night...',
#   'tmr',
#   "u'll",
#   'brand',
#   'new',
#   'room',
#   '2',
#   'sleep',
#   'in...'],
#  ['love',
#   'decision,',
#   'feeling.',
#   'could',
#   'decide',
#   'love,',
#   'then,',
#   'life',
#   'would',
#   'much',
#   'simpler,',
#   'less',
#   'magical'],
#  ['welp', 'apparently', 'retired'],
#  ['sort',
#   'code',
#   'acc',
#   '.',
#   'bank',
#   'natwest.',
#   'reply',
#   'confirm',
#   "i've",
#   'sent',
#   'right',
#   'person!'],
#  ['@'],
#  ['u', 'sure', 'u', "can't", 'take', 'sick', 'time?'],
#  ['urgent!',
#   'trying',
#   'contact',
#   'u.',
#   'today',
#   'draw',
#   'show',
#   '£800',
#   'prize',
#   'guaranteed.',
#   'call',
#   '09050001808',
#   'land',
#   'line.',
#   'claim',
#   'm95.',
#   'valid12hrs'],
#  ['watching',
#   'cartoon,',
#   'listening',
#   'music',
#   '&amp;',
#   'eve',
#   'go',
#   'temple',
#   '&amp;',
#   'church..',
#   'u?'],
#  ['yo',
#   'chad',
#   'gymnastics',
#   'class',
#   'wanna',
#   'take?',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'full..'],
#  ['much', 'buzy'],
#  ['better', 'still', 'catch', 'let', 'ask', 'sell', '&lt;#&gt;', 'me.'],
#  ['sure', 'night', 'menu.', '.', '.', 'know', 'noon', 'menu'],
#  ['u',
#   'want',
#   'come',
#   'back?.a',
#   'beautiful',
#   'necklace',
#   'token',
#   'heart',
#   'you.thats',
#   'give',
#   'wife',
#   'liking.be',
#   'see..no',
#   'one',
#   'give',
#   'that.dont',
#   'call',
#   'me.i',
#   'wait',
#   'till',
#   'come.'],
#  ['willing', 'go', 'aptitude', 'class.'],
#  ['wont', 'b', '2.15', 'trying', '2', 'sort', 'house', 'out,', 'ok?'],
#  ['yar',
#   'lor',
#   'wan',
#   '2',
#   'go',
#   'c',
#   'horse',
#   'racing',
#   'today',
#   'mah,',
#   'eat',
#   'earlier',
#   'lor.',
#   'ate',
#   'chicken',
#   'rice.',
#   'u?'],
#  ['haha', 'awesome,', 'omw', 'back'],
#  ['yup', 'thk', 'e', 'shop', 'close', 'lor.'],
#  ['account', 'number?'],
#  ['eh', 'u', 'send', 'wrongly', 'lar...'],
#  ['hey',
#   'ad',
#   'crap',
#   'nite',
#   'borin',
#   'without',
#   'ya',
#   '2',
#   'boggy',
#   'u',
#   'boring',
#   'biatch!',
#   'thanx',
#   'u',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk'],
#  ['dont',
#   'hesitate.',
#   'know',
#   'second',
#   'time',
#   'weakness',
#   'like',
#   'that.',
#   'keep',
#   'notebook',
#   'eat',
#   'day',
#   'anything',
#   'changed',
#   'day',
#   'sure',
#   'nothing'],
#  ['hey', 'pay.', 'salary', 'de.', '&lt;#&gt;', '.'],
#  ['another', 'month.', 'need', 'chocolate', 'weed', 'alcohol.'],
#  ['started',
#   'searching',
#   'get',
#   'job',
#   'days.he',
#   'great',
#   'potential',
#   'talent.'],
#  ['reckon', 'need', 'town', 'eightish', 'walk', '*', 'carpark.'],
#  ['congrats!',
#   '2',
#   'mobile',
#   '3g',
#   'videophones',
#   'r',
#   'yours.',
#   'call',
#   '09063458130',
#   'now!',
#   'videochat',
#   'wid',
#   'mates,',
#   'play',
#   'java',
#   'games,',
#   'dload',
#   'polyph',
#   'music,',
#   'noline',
#   'rentl.'],
#  ['look', 'fuckin', 'time.', 'fuck', 'think'],
#  ['yo', 'guess', 'dropped'],
#  ['carlos', 'say', "he'll", 'mu', '&lt;#&gt;', 'minute'],
#  ["i'm", 'office', '.', 'call', '&lt;#&gt;', 'min:)'],
#  ['geeee',
#   '...',
#   'miss',
#   'already,',
#   'know',
#   '?',
#   'think',
#   'about.',
#   'fuck,',
#   "can't",
#   'wait',
#   'till',
#   'next',
#   'year',
#   'together',
#   '...',
#   '*loving',
#   'kiss*'],
#  ['yun',
#   'ah.the',
#   'ubi',
#   'one',
#   'say',
#   'ü',
#   'wan',
#   'call',
#   'tomorrow.call',
#   '67441233',
#   'look',
#   'irene.ere',
#   'got',
#   'bus8,22,65,61,66,382.',
#   'ubi',
#   'cres,ubi',
#   'tech',
#   'park.6ph',
#   '1st',
#   '5wkg',
#   'days.èn'],
#  ['ugh.', 'gotta', 'drive', 'back', 'sd', 'la.', 'butt', 'sore.'],
#  ['26th', 'july'],
#  ['hi',
#   'im',
#   'relaxing',
#   'time',
#   'ever!',
#   'get',
#   '7am',
#   'every',
#   'day!',
#   'party',
#   'good',
#   'night?',
#   'get',
#   'home',
#   'tomorrow',
#   '5ish.'],
#  ['ü...',
#   'ü',
#   'wan',
#   'come',
#   'come',
#   'lor...',
#   'din',
#   'c',
#   'stripe',
#   'skirt...'],
#  ['xmas',
#   'story',
#   'peace..',
#   'xmas',
#   'msg',
#   'love..',
#   'xmas',
#   'miracle',
#   'jesus..',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   '&amp;',
#   'wish',
#   'u',
#   'merry',
#   'xmas...'],
#  ["can't,", 'number!'],
#  ['change', 'again...', 'e', 'one', 'next', 'escalator...'],
#  ['yetunde', "i'm", 'class', 'run', 'water', 'make', 'ok.', 'pls', 'now.'],
#  ['lot',
#   'happened',
#   'here.',
#   'feel',
#   'quiet.',
#   'beth',
#   'aunt',
#   'charlie',
#   'working',
#   'lots.',
#   'helen',
#   'mo.',
#   'been?'],
#  ['ü',
#   'wait',
#   '4',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar.',
#   'dun',
#   'c',
#   'ü',
#   'go',
#   'get',
#   'car',
#   'come',
#   'back',
#   'n',
#   'pick',
#   'ü.'],
#  ...]

# %% [markdown]
# # Create Tf-IDF and N-Grams (Term Frequecy, and Inverse Term Frequency)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
print(corpus)

# Initialize TfidfVectorizer
tfidf = TfidfVectorizer(max_features=100)

# Fit and transform the corpus
X = tfidf.fit_transform(corpus).toarray()

print(X)
# Out:
# [['go', 'jurong', 'point,', 'crazy..', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet...', 'cine', 'got', 'amore', 'wat...'], ['ok', 'lar...', 'joking', 'wif', 'u', 'oni...'], ['free', 'entry', '2', 'wkly', 'comp', 'win', 'fa', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', 'fa', '87121', 'receive', 'entry', 'question(std', 'txt', "rate)t&c's", 'apply', "08452810075over18's"], ['u', 'dun', 'say', 'early', 'hor...', 'u', 'c', 'already', 'say...'], ['nah', 'think', 'go', 'usf,', 'life', 'around', 'though'], ['freemsg', 'hey', 'darling', '3', "week's", 'word', 'back!', "i'd", 'like', 'fun', 'still?', 'tb', 'ok!', 'xxx', 'std', 'chgs', 'send,', '£1.50', 'rcv'], ['even', 'brother', 'like', 'speak', 'me.', 'treat', 'like', 'aid', 'patent.'], ['per', 'request', "'melle", 'melle', '(oru', 'minnaminunginte', 'nurungu', "vettam)'", 'set', 'callertune', 'callers.', 'press', '*9', 'copy', 'friend', 'callertune'], ['winner!!', 'valued', 'network', 'customer', 'selected', 'receivea', '£900', 'prize', 'reward!', 'claim', 'call', '09061701461.', 'claim', 'code', 'kl341.', 'valid', '12', 'hour', 'only.'], ['mobile', '11', 'month', 'more?', 'u', 'r', 'entitled', 'update', 'latest', 'colour', 'mobile', 'camera', 'free!', 'call', 'mobile', 'update', 'co', 'free', '08002986030'], ["i'm", 'gonna', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight,', 'k?', "i've", 'cried', 'enough', 'today.'], ['six', 'chance', 'win', 'cash!', '100', '20,000', 'pound', 'txt>', 'csh11', 'send', '87575.', 'cost', '150p/day,', '6days,', '16+', 'tsandcs', 'apply', 'reply', 'hl', '4', 'info'], ['urgent!', '1', 'week', 'free', 'membership', '£100,000', 'prize', 'jackpot!', 'txt', 'word:', 'claim', 'no:', '81010', 't&c', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18'], ["i've", 'searching', 'right', 'word', 'thank', 'breather.', 'promise', 'wont', 'take', 'help', 'granted', 'fulfil', 'promise.', 'wonderful', 'blessing', 'times.'], ['date', 'sunday', 'will!!'], ['xxxmobilemovieclub:', 'use', 'credit,', 'click', 'wap', 'link', 'next', 'txt', 'message', 'click', 'here>>', 'http://wap.', 'xxxmobilemovieclub.com?n=qjkgighjjgcbl'], ['oh', "k...i'm", 'watching', 'here:)'], ['eh', 'u', 'remember', '2', 'spell', 'name...', 'yes', 'did.', 'v', 'naughty', 'make', 'v', 'wet.'], ['fine', 'that\x92s', 'way', 'u', 'feel.', 'that\x92s', 'way', 'gota', 'b'], ['england', 'v', 'macedonia', '-', 'dont', 'miss', 'goals/team', 'news.', 'txt', 'ur', 'national', 'team', '87077', 'eg', 'england', '87077', 'try:wales,', 'scotland', '4txt/ú1.20', 'poboxox36504w45wq', '16+'], ['seriously', 'spell', 'name?'], ['i‘m', 'going', 'try', '2', 'month', 'ha', 'ha', 'joking'], ['ü', 'pay', 'first', 'lar...', 'da', 'stock', 'comin...'], ['aft', 'finish', 'lunch', 'go', 'str', 'lor.', 'ard', '3', 'smth', 'lor.', 'u', 'finish', 'ur', 'lunch', 'already?'], ['ffffffffff.', 'alright', 'way', 'meet', 'sooner?'], ['forced', 'eat', 'slice.', "i'm", 'really', 'hungry', 'tho.', 'sucks.', 'mark', 'getting', 'worried.', 'know', "i'm", 'sick', 'turn', 'pizza.', 'lol'], ['lol', 'always', 'convincing.'], ['catch', 'bus', '?', 'frying', 'egg', '?', 'make', 'tea?', 'eating', "mom's", 'left', 'dinner', '?', 'feel', 'love', '?'], ["i'm", 'back', '&amp;', "we're", 'packing', 'car', 'now,', "i'll", 'let', 'know', "there's", 'room'], ['ahhh.', 'work.', 'vaguely', 'remember', 'that!', 'feel', 'like?', 'lol'], ['wait', "that's", 'still', 'clear,', 'sure', 'sarcastic', "that's", 'x', 'want', 'live', 'u'], ['yeah', 'got', '2', 'v', 'apologetic.', 'n', 'fallen', 'actin', 'like', 'spoilt', 'child', 'got', 'caught', 'that.', 'till', '2!', 'go', 'there!', 'badly', 'cheers.', 'you?'], ['k', 'tell', 'anything', 'you.'], ['fear', 'fainting', 'housework', 'did?', 'quick', 'cuppa'], ['thanks', 'subscription', 'ringtone', 'uk', 'mobile', 'charged', '£5/month', 'please', 'confirm', 'replying', 'yes', 'no.', 'reply', 'charged'], ['yup...', 'ok', 'go', 'home', 'look', 'timing', 'msg', 'ü', 'again...', 'xuh ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 8
#       5 tfidf = TfidfVectorizer(max_features=100)
#       7 # Fit and transform the corpus
# ----> 8 X = tfidf.fit_transform(corpus).toarray()
#      10 print(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:2091, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2084 self._check_params()
#    2085 self._tfidf = TfidfTransformer(
#    2086     norm=self.norm,
#    2087     use_idf=self.use_idf,
#    2088     smooth_idf=self.smooth_idf,
#    2089     sublinear_tf=self.sublinear_tf,
#    2090 )
# -> 2091 X = super().fit_transform(raw_documents)
#    2092 self._tfidf.fit(X)
#    2093 # X is already a transformed view of raw_documents so
#    2094 # we set copy to False
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1372, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1364             warnings.warn(
#    1365                 "Upper case characters found in"
#    1366                 " vocabulary while 'lowercase'"
#    1367                 " is True. These entries will not"
#    1368                 " be matched with any documents"
#    1369             )
#    1370             break
# -> 1372 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1374 if self.binary:
#    1375     X.data.fill(1)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1259, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1257 for doc in raw_documents:
#    1258     feature_counter = {}
# -> 1259     for feature in analyze(doc):
#    1260         try:
#    1261             feature_idx = vocabulary[feature]
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:108, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     106 else:
#     107     if preprocessor is not None:
# --> 108         doc = preprocessor(doc)
#     109     if tokenizer is not None:
#     110         doc = tokenizer(doc)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:66, in _preprocess(doc, accent_function, lower)
#      47 """Chain together an optional series of text preprocessing steps to
#      48 apply to a document.
#      49
#    (...)
#      63     preprocessed string
#      64 """
#      65 if lower:
# ---> 66     doc = doc.lower()
#      67 if accent_function is not None:
#      68     doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the corpus
corpus = ["This is the first document.",
          "This document is the second document.",
          "And this is the third one.",
          "Is this the first document?"]

# Initialize TfidfVectorizer
tfidf = TfidfVectorizer(max_features=100)

# Fit and transform the corpus
X = tfidf.fit_transform(corpus).toarray()

print(X)
# Out:
# [[0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]
#  [0.         0.6876236  0.         0.28108867 0.         0.53864762
#   0.28108867 0.         0.28108867]
#  [0.51184851 0.         0.         0.26710379 0.51184851 0.
#   0.26710379 0.51184851 0.26710379]
#  [0.         0.46979139 0.58028582 0.38408524 0.         0.
#   0.38408524 0.         0.38408524]]

# %%
import numpy as np
np.set_printoptions(edgeitems=30, linewidth=100000, 
    formatter=dict(float=lambda x: "%.3g" % x))

# %%
X
# Out:
# array([[0, 0.47, 0.58, 0.384, 0, 0, 0.384, 0, 0.384],
#        [0, 0.688, 0, 0.281, 0, 0.539, 0.281, 0, 0.281],
#        [0.512, 0, 0, 0.267, 0.512, 0, 0.267, 0.512, 0.267],
#        [0, 0.47, 0.58, 0.384, 0, 0, 0.384, 0, 0.384]])

# %% [markdown]
# # N-Grams:--->

# %%
tfidf=TfidfVectorizer(max_features=100,ngram_range=(2,2))
X=tfidf.fit_transform(corpus).toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 2
#       1 tfidf=TfidfVectorizer(max_features=100,ngram_range=(2,2))
# ----> 2 X=tfidf.fit_transform(corpus).toarray()
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:2091, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2084 self._check_params()
#    2085 self._tfidf = TfidfTransformer(
#    2086     norm=self.norm,
#    2087     use_idf=self.use_idf,
#    2088     smooth_idf=self.smooth_idf,
#    2089     sublinear_tf=self.sublinear_tf,
#    2090 )
# -> 2091 X = super().fit_transform(raw_documents)
#    2092 self._tfidf.fit(X)
#    2093 # X is already a transformed view of raw_documents so
#    2094 # we set copy to False
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1372, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1364             warnings.warn(
#    1365                 "Upper case characters found in"
#    1366                 " vocabulary while 'lowercase'"
#    1367                 " is True. These entries will not"
#    1368                 " be matched with any documents"
#    1369             )
#    1370             break
# -> 1372 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1374 if self.binary:
#    1375     X.data.fill(1)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1259, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1257 for doc in raw_documents:
#    1258     feature_counter = {}
# -> 1259     for feature in analyze(doc):
#    1260         try:
#    1261             feature_idx = vocabulary[feature]
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:108, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     106 else:
#     107     if preprocessor is not None:
# --> 108         doc = preprocessor(doc)
#     109     if tokenizer is not None:
#     110         doc = tokenizer(doc)
#
# File ~\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:66, in _preprocess(doc, accent_function, lower)
#      47 """Chain together an optional series of text preprocessing steps to
#      48 apply to a document.
#      49
#    (...)
#      63     preprocessed string
#      64 """
#      65 if lower:
# ---> 66     doc = doc.lower()
#      67 if accent_function is not None:
#      68     doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
tfidf.vocabulary_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 tfidf.vocabulary_
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'vocabulary_'

# %%
X
